# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## GPD 1

# %%
data = pd.read_excel(r'C:\Users\MR38804\Documents\Network Graph\GB Request\GB Transactions.xlsx', sheet_name='GB Only')

# %%
data
# Out:
#                  BASE DATE        GCIF         CIF        AMOUNT  \
# 0      2022-08-15 00:00:00  G406240135         NaN  3.950000e+10
# 1      2022-08-30 00:00:00  G406240135         NaN  3.160000e+10
# 2      2022-08-30 00:00:00  G406240135         NaN  1.900000e+09
# 3      2022-08-01 00:00:00  G808537518         NaN  5.000000e+11
# 4                      NaN  G808537518         NaN  3.169426e+10
# ...                    ...         ...         ...           ...
# 35562             20220831  G503045999   6794289.0  5.000000e+05
# 35563             20220831  G503045999   6794289.0  7.099200e+07
# 35564             20220831  G409433240  12508370.0  2.500000e+07
# 35565             20220831  G409433240  12508370.0  1.576500e+07
# 35566             20220831  G409433240  12508370.0  6.576500e+07
#
#        ORIGIN ACCT NO                   ORIGIN NAME        ORIGIN BANK  \
# 0        2.407001e+09   ABC PRESIDENT INDONESIA, PT   BANK BII MAYBANK
# 1        2.407001e+09   ABC PRESIDENT INDONESIA, PT   BANK BII MAYBANK
# 2        2.407001e+09   ABC PRESIDENT INDONESIA, PT   BANK BII MAYBANK
# 3        2.596003e+09  ADIRA DINAMIKA MULTI FINANCE   BANK BII MAYBANK
# 4                 NaN  ADIRA DINAMIKA MULTI FINANCE   BANK BII MAYBANK
# ...               ...                           ...                ...
# 35562             NaN                        SHELLY           BANK BCA
# 35563             NaN       69966491 SD CITRA KASIH  BANK MALUKU MALUT
# 35564             NaN          GUNWANTI HARDASMAL K           BANK BCA
# 35565             NaN          GUNWANTI HARDASMAL K           BANK BCA
# 35566             NaN        PATRICK WILLIAM DUNCAN           BANK BCA
#
#       BENEFICIARY ACCT NO                        BENEFICIARY NAME  \
# 0            001180967068              PT ABC PRESIDENT INDONESIA
# 1            001180967068              PT ABC PRESIDENT INDONESIA
# 2            001180967068              PT ABC PRESIDENT INDONESIA
# 3                36479855                                       0
# 4                     NaN                             BNP PARIBAS
# ...                   ...                                     ...
# 35562          2002111888                    YAYASAN CITRA BERKAT
# 35563          2093223000                    YAYASAN CITRA BERKAT
# 35564          2016302989  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
# 35565          2016302989  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
# 35566          2016302989  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
#
#                                BENEFICIARY BANK LoB TRX TYPE    IN/OUT
# 0      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 1      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 2      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 3                                  BANK DANAMON  GB     RTGS  OUTGOING
# 4                           JP MORGAN CHASE, NY  GB       TT  OUTGOING
# ...                                         ...  ..      ...       ...
# 35562                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35563                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35564                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35565                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35566                          BANK BII MAYBANK  GB      SKN  INCOMING
#
# [35567 rows x 13 columns]

# %%
data.drop(['BASE DATE'], inplace=True, axis=1)

# %%
data.columns
# Out:
# Index(['GCIF', 'CIF', 'AMOUNT', 'ORIGIN ACCT NO', 'ORIGIN NAME', 'ORIGIN BANK',
#        'BENEFICIARY ACCT NO', 'BENEFICIARY NAME', 'BENEFICIARY BANK', 'LoB',
#        'TRX TYPE', 'IN/OUT'],
#       dtype='object')

# %%
data
# Out:
#              GCIF         CIF        AMOUNT  ORIGIN ACCT NO  \
# 0      G406240135         NaN  3.950000e+10    2.407001e+09
# 1      G406240135         NaN  3.160000e+10    2.407001e+09
# 2      G406240135         NaN  1.900000e+09    2.407001e+09
# 3      G808537518         NaN  5.000000e+11    2.596003e+09
# 4      G808537518         NaN  3.169426e+10             NaN
# ...           ...         ...           ...             ...
# 35562  G503045999   6794289.0  5.000000e+05             NaN
# 35563  G503045999   6794289.0  7.099200e+07             NaN
# 35564  G409433240  12508370.0  2.500000e+07             NaN
# 35565  G409433240  12508370.0  1.576500e+07             NaN
# 35566  G409433240  12508370.0  6.576500e+07             NaN
#
#                         ORIGIN NAME        ORIGIN BANK BENEFICIARY ACCT NO  \
# 0       ABC PRESIDENT INDONESIA, PT   BANK BII MAYBANK        001180967068
# 1       ABC PRESIDENT INDONESIA, PT   BANK BII MAYBANK        001180967068
# 2       ABC PRESIDENT INDONESIA, PT   BANK BII MAYBANK        001180967068
# 3      ADIRA DINAMIKA MULTI FINANCE   BANK BII MAYBANK            36479855
# 4      ADIRA DINAMIKA MULTI FINANCE   BANK BII MAYBANK                 NaN
# ...                             ...                ...                 ...
# 35562                        SHELLY           BANK BCA          2002111888
# 35563       69966491 SD CITRA KASIH  BANK MALUKU MALUT          2093223000
# 35564          GUNWANTI HARDASMAL K           BANK BCA          2016302989
# 35565          GUNWANTI HARDASMAL K           BANK BCA          2016302989
# 35566        PATRICK WILLIAM DUNCAN           BANK BCA          2016302989
#
#                              BENEFICIARY NAME  \
# 0                  PT ABC PRESIDENT INDONESIA
# 1                  PT ABC PRESIDENT INDONESIA
# 2                  PT ABC PRESIDENT INDONESIA
# 3                                           0
# 4                                 BNP PARIBAS
# ...                                       ...
# 35562                    YAYASAN CITRA BERKAT
# 35563                    YAYASAN CITRA BERKAT
# 35564  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
# 35565  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
# 35566  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
#
#                                BENEFICIARY BANK LoB TRX TYPE    IN/OUT
# 0      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 1      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 2      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 3                                  BANK DANAMON  GB     RTGS  OUTGOING
# 4                           JP MORGAN CHASE, NY  GB       TT  OUTGOING
# ...                                         ...  ..      ...       ...
# 35562                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35563                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35564                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35565                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35566                          BANK BII MAYBANK  GB      SKN  INCOMING
#
# [35567 rows x 12 columns]

# %%
#cleanse name values - origin name
data['ORIGIN NAME']=data['ORIGIN NAME'].str.upper()
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('PT',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('TBK',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('.',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('-',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace(',',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace("''"," ")
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('//',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('\s+',' ',regex=True)
data['ORIGIN NAME']=data['ORIGIN NAME'].str.strip()
# Out:
# <ipython-input-7-a20c479fbe60>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('.',' ')

# %%
#cleanse name values - benficiary name
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.upper()
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('PT',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('TBK',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('.',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('-',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace(',',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace("''"," ")
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('//',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('\s+',' ',regex=True)
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.strip()
# Out:
# <ipython-input-8-f370484ed1e1>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('.',' ')

# %%
data
# Out:
#              GCIF         CIF        AMOUNT  ORIGIN ACCT NO  \
# 0      G406240135         NaN  3.950000e+10    2.407001e+09
# 1      G406240135         NaN  3.160000e+10    2.407001e+09
# 2      G406240135         NaN  1.900000e+09    2.407001e+09
# 3      G808537518         NaN  5.000000e+11    2.596003e+09
# 4      G808537518         NaN  3.169426e+10             NaN
# ...           ...         ...           ...             ...
# 35562  G503045999   6794289.0  5.000000e+05             NaN
# 35563  G503045999   6794289.0  7.099200e+07             NaN
# 35564  G409433240  12508370.0  2.500000e+07             NaN
# 35565  G409433240  12508370.0  1.576500e+07             NaN
# 35566  G409433240  12508370.0  6.576500e+07             NaN
#
#                         ORIGIN NAME        ORIGIN BANK BENEFICIARY ACCT NO  \
# 0           ABC PRESIDENT INDONESIA   BANK BII MAYBANK        001180967068
# 1           ABC PRESIDENT INDONESIA   BANK BII MAYBANK        001180967068
# 2           ABC PRESIDENT INDONESIA   BANK BII MAYBANK        001180967068
# 3      ADIRA DINAMIKA MULTI FINANCE   BANK BII MAYBANK            36479855
# 4      ADIRA DINAMIKA MULTI FINANCE   BANK BII MAYBANK                 NaN
# ...                             ...                ...                 ...
# 35562                        SHELLY           BANK BCA          2002111888
# 35563       69966491 SD CITRA KASIH  BANK MALUKU MALUT          2093223000
# 35564          GUNWANTI HARDASMAL K           BANK BCA          2016302989
# 35565          GUNWANTI HARDASMAL K           BANK BCA          2016302989
# 35566        PATRICK WILLIAM DUNCAN           BANK BCA          2016302989
#
#                              BENEFICIARY NAME  \
# 0                     ABC PRESIDENT INDONESIA
# 1                     ABC PRESIDENT INDONESIA
# 2                     ABC PRESIDENT INDONESIA
# 3                                         NaN
# 4                                 BNP PARIBAS
# ...                                       ...
# 35562                    YAYASAN CITRA BERKAT
# 35563                    YAYASAN CITRA BERKAT
# 35564  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
# 35565  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
# 35566  YAY NORTH JAKARTA INTERNATIONAL SCHOOL
#
#                                BENEFICIARY BANK LoB TRX TYPE    IN/OUT
# 0      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 1      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 2      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB     RTGS  OUTGOING
# 3                                  BANK DANAMON  GB     RTGS  OUTGOING
# 4                           JP MORGAN CHASE, NY  GB       TT  OUTGOING
# ...                                         ...  ..      ...       ...
# 35562                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35563                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35564                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35565                          BANK BII MAYBANK  GB      SKN  INCOMING
# 35566                          BANK BII MAYBANK  GB      SKN  INCOMING
#
# [35567 rows x 12 columns]

# %%
dataInc = data[data['IN/OUT']=='INCOMING']
dataInc.columns = ['DEBTOR GCIF', 'DEBTOR CIF', 'AMOUNT_TX_IDR', 'SENDER/RECIPIENT ACCOUNT', 
'SENDER/RECIPIENT NAME', 'SENDER/RECIPIENT BANK', 'DEBTOR ACCOUNT', 'DEBTOR NAME', 'DEBTOR BANK',
'LOB', 'CHANNEL','TYPE']

# %%
dataInc
# Out:
#       DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR  SENDER/RECIPIENT ACCOUNT  \
# 8      G309796571  12852079.0      2000000.0                       NaN
# 32     G200547461   2932158.0       675000.0                       NaN
# 33     G200547461   2932158.0       500000.0                       NaN
# 34     G200547461   2932158.0       500000.0                       NaN
# 35     G200547461   2932158.0       500000.0                       NaN
# ...           ...         ...            ...                       ...
# 35562  G503045999   6794289.0       500000.0                       NaN
# 35563  G503045999   6794289.0     70992000.0                       NaN
# 35564  G409433240  12508370.0     25000000.0                       NaN
# 35565  G409433240  12508370.0     15765000.0                       NaN
# 35566  G409433240  12508370.0     65765000.0                       NaN
#
#               SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK DEBTOR ACCOUNT  \
# 8      AGROMATE INTERNATIONAL E LTD    BANK UOB INDONESIA     2596000412
# 32          AGROTUNGGAL JAYAMANDIRI          BANK MANDIRI     2003070866
# 33          AGROTUNGGAL JAYAMANDIRI          BANK MANDIRI     2003070866
# 34          AGROTUNGGAL JAYAMANDIRI          BANK MANDIRI     2003070866
# 35          AGROTUNGGAL JAYAMANDIRI          BANK MANDIRI     2003070866
# ...                             ...                   ...            ...
# 35562                        SHELLY              BANK BCA     2002111888
# 35563       69966491 SD CITRA KASIH     BANK MALUKU MALUT     2093223000
# 35564          GUNWANTI HARDASMAL K              BANK BCA     2016302989
# 35565          GUNWANTI HARDASMAL K              BANK BCA     2016302989
# 35566        PATRICK WILLIAM DUNCAN              BANK BCA     2016302989
#
#                                   DEBTOR NAME       DEBTOR BANK   LOB CHANNEL  \
# 8                AGROMATE INTERNATIONAL E LTD  BANK BII MAYBANK    GB     SKN
# 32           YAYASAN BUDDHA TZU CHI INDONESIA  BANK BII MAYBANK  RSME     SKN
# 33           YAYASAN BUDDHA TZU CHI INDONESIA  BANK BII MAYBANK  RSME     SKN
# 34           YAYASAN BUDDHA TZU CHI INDONESIA  BANK BII MAYBANK  RSME     SKN
# 35           YAYASAN BUDDHA TZU CHI INDONESIA  BANK BII MAYBANK  RSME     SKN
# ...                                       ...               ...   ...     ...
# 35562                    YAYASAN CITRA BERKAT  BANK BII MAYBANK    GB     SKN
# 35563                    YAYASAN CITRA BERKAT  BANK BII MAYBANK    GB     SKN
# 35564  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK    GB     SKN
# 35565  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK    GB     SKN
# 35566  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK    GB     SKN
#
#            TYPE
# 8      INCOMING
# 32     INCOMING
# 33     INCOMING
# 34     INCOMING
# 35     INCOMING
# ...         ...
# 35562  INCOMING
# 35563  INCOMING
# 35564  INCOMING
# 35565  INCOMING
# 35566  INCOMING
#
# [16948 rows x 12 columns]

# %%
dataOut = data[data['IN/OUT']=='OUTGOING']
dataOut.columns = ['DEBTOR GCIF', 'DEBTOR CIF', 'AMOUNT_TX_IDR', 'DEBTOR ACCOUNT', 'DEBTOR NAME', 
'DEBTOR BANK', 'SENDER/RECIPIENT ACCOUNT', 'SENDER/RECIPIENT NAME', 'SENDER/RECIPIENT BANK', 'LOB',
'CHANNEL', 'TYPE']

# %%
dataOut
# Out:
#       DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR  DEBTOR ACCOUNT  \
# 0      G406240135         NaN   3.950000e+10    2.407001e+09
# 1      G406240135         NaN   3.160000e+10    2.407001e+09
# 2      G406240135         NaN   1.900000e+09    2.407001e+09
# 3      G808537518         NaN   5.000000e+11    2.596003e+09
# 4      G808537518         NaN   3.169426e+10             NaN
# ...           ...         ...            ...             ...
# 35227  G809640246  12701404.0   5.327200e+06    2.573000e+09
# 35228  G809640246  12701404.0   4.352500e+06    2.573000e+09
# 35229  G809640246  12701404.0   2.785500e+06    2.573000e+09
# 35230  G809640246  12701404.0   1.148800e+06    2.573000e+09
# 35355  G709296842         NaN   3.263733e+06    1.620620e+11
#
#                         DEBTOR NAME       DEBTOR BANK  \
# 0           ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 1           ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 2           ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 3      ADIRA DINAMIKA MULTI FINANCE  BANK BII MAYBANK
# 4      ADIRA DINAMIKA MULTI FINANCE  BANK BII MAYBANK
# ...                             ...               ...
# 35227              ENAK JAYA MAKMUR  BANK BII MAYBANK
# 35228              ENAK JAYA MAKMUR  BANK BII MAYBANK
# 35229              ENAK JAYA MAKMUR  BANK BII MAYBANK
# 35230              ENAK JAYA MAKMUR  BANK BII MAYBANK
# 35355   USAHAWISATA SAFARI EKSKURSI  BANK BII MAYBANK
#
#       SENDER/RECIPIENT ACCOUNT    SENDER/RECIPIENT NAME  \
# 0                 001180967068  ABC PRESIDENT INDONESIA
# 1                 001180967068  ABC PRESIDENT INDONESIA
# 2                 001180967068  ABC PRESIDENT INDONESIA
# 3                     36479855                      NaN
# 4                          NaN              BNP PARIBAS
# ...                        ...                      ...
# 35227               3880149970             SO GOOD FOOD
# 35228               3880149970             SO GOOD FOOD
# 35229               3880149970             SO GOOD FOOD
# 35230               3880149970             SO GOOD FOOD
# 35355                        0    WENANG PERMAI SENTOSA
#
#                           SENDER/RECIPIENT BANK   LOB CHANNEL      TYPE
# 0      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)    GB    RTGS  OUTGOING
# 1      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)    GB    RTGS  OUTGOING
# 2      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)    GB    RTGS  OUTGOING
# 3                                  BANK DANAMON    GB    RTGS  OUTGOING
# 4                           JP MORGAN CHASE, NY    GB      TT  OUTGOING
# ...                                         ...   ...     ...       ...
# 35227                                  BANK BCA  SME+     SKN  OUTGOING
# 35228                                  BANK BCA  SME+     SKN  OUTGOING
# 35229                                  BANK BCA  SME+     SKN  OUTGOING
# 35230                                  BANK BCA  SME+     SKN  OUTGOING
# 35355                                  BANK BNI  RSME     M2U  OUTGOING
#
# [18619 rows x 12 columns]

# %%
data = pd.concat([dataOut, dataInc])

# %%
data['DEBTOR BANK'].value_counts()
# Out:
# BANK BII MAYBANK    35567
# Name: DEBTOR BANK, dtype: int64

# %%
data
# Out:
#       DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR DEBTOR ACCOUNT  \
# 0      G406240135         NaN   3.950000e+10   2407000799.0
# 1      G406240135         NaN   3.160000e+10   2407000799.0
# 2      G406240135         NaN   1.900000e+09   2407000799.0
# 3      G808537518         NaN   5.000000e+11   2596003270.0
# 4      G808537518         NaN   3.169426e+10            NaN
# ...           ...         ...            ...            ...
# 35562  G503045999   6794289.0   5.000000e+05     2002111888
# 35563  G503045999   6794289.0   7.099200e+07     2093223000
# 35564  G409433240  12508370.0   2.500000e+07     2016302989
# 35565  G409433240  12508370.0   1.576500e+07     2016302989
# 35566  G409433240  12508370.0   6.576500e+07     2016302989
#
#                                   DEBTOR NAME       DEBTOR BANK  \
# 0                     ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 1                     ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 2                     ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 3                ADIRA DINAMIKA MULTI FINANCE  BANK BII MAYBANK
# 4                ADIRA DINAMIKA MULTI FINANCE  BANK BII MAYBANK
# ...                                       ...               ...
# 35562                    YAYASAN CITRA BERKAT  BANK BII MAYBANK
# 35563                    YAYASAN CITRA BERKAT  BANK BII MAYBANK
# 35564  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK
# 35565  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK
# 35566  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK
#
#       SENDER/RECIPIENT ACCOUNT    SENDER/RECIPIENT NAME  \
# 0                 001180967068  ABC PRESIDENT INDONESIA
# 1                 001180967068  ABC PRESIDENT INDONESIA
# 2                 001180967068  ABC PRESIDENT INDONESIA
# 3                     36479855                      NaN
# 4                          NaN              BNP PARIBAS
# ...                        ...                      ...
# 35562                      NaN                   SHELLY
# 35563                      NaN  69966491 SD CITRA KASIH
# 35564                      NaN     GUNWANTI HARDASMAL K
# 35565                      NaN     GUNWANTI HARDASMAL K
# 35566                      NaN   PATRICK WILLIAM DUNCAN
#
#                           SENDER/RECIPIENT BANK LOB CHANNEL      TYPE
# 0      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB    RTGS  OUTGOING
# 1      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB    RTGS  OUTGOING
# 2      THE HONGKONG & SHANGHAI B.C. (BANK HSBC)  GB    RTGS  OUTGOING
# 3                                  BANK DANAMON  GB    RTGS  OUTGOING
# 4                           JP MORGAN CHASE, NY  GB      TT  OUTGOING
# ...                                         ...  ..     ...       ...
# 35562                                  BANK BCA  GB     SKN  INCOMING
# 35563                         BANK MALUKU MALUT  GB     SKN  INCOMING
# 35564                                  BANK BCA  GB     SKN  INCOMING
# 35565                                  BANK BCA  GB     SKN  INCOMING
# 35566                                  BANK BCA  GB     SKN  INCOMING
#
# [35567 rows x 12 columns]

# %%
data['SENDER/RECIPIENT BANK']='EXTERNAL'

# %%
data.fillna('NO DATA', inplace=True)

# %%
data
# Out:
#       DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR DEBTOR ACCOUNT  \
# 0      G406240135     NO DATA   3.950000e+10   2407000799.0
# 1      G406240135     NO DATA   3.160000e+10   2407000799.0
# 2      G406240135     NO DATA   1.900000e+09   2407000799.0
# 3      G808537518     NO DATA   5.000000e+11   2596003270.0
# 4      G808537518     NO DATA   3.169426e+10        NO DATA
# ...           ...         ...            ...            ...
# 35562  G503045999   6794289.0   5.000000e+05     2002111888
# 35563  G503045999   6794289.0   7.099200e+07     2093223000
# 35564  G409433240  12508370.0   2.500000e+07     2016302989
# 35565  G409433240  12508370.0   1.576500e+07     2016302989
# 35566  G409433240  12508370.0   6.576500e+07     2016302989
#
#                                   DEBTOR NAME       DEBTOR BANK  \
# 0                     ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 1                     ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 2                     ABC PRESIDENT INDONESIA  BANK BII MAYBANK
# 3                ADIRA DINAMIKA MULTI FINANCE  BANK BII MAYBANK
# 4                ADIRA DINAMIKA MULTI FINANCE  BANK BII MAYBANK
# ...                                       ...               ...
# 35562                    YAYASAN CITRA BERKAT  BANK BII MAYBANK
# 35563                    YAYASAN CITRA BERKAT  BANK BII MAYBANK
# 35564  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK
# 35565  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK
# 35566  YAY NORTH JAKARTA INTERNATIONAL SCHOOL  BANK BII MAYBANK
#
#       SENDER/RECIPIENT ACCOUNT    SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK  \
# 0                 001180967068  ABC PRESIDENT INDONESIA              EXTERNAL
# 1                 001180967068  ABC PRESIDENT INDONESIA              EXTERNAL
# 2                 001180967068  ABC PRESIDENT INDONESIA              EXTERNAL
# 3                     36479855                  NO DATA              EXTERNAL
# 4                      NO DATA              BNP PARIBAS              EXTERNAL
# ...                        ...                      ...                   ...
# 35562                  NO DATA                   SHELLY              EXTERNAL
# 35563                  NO DATA  69966491 SD CITRA KASIH              EXTERNAL
# 35564                  NO DATA     GUNWANTI HARDASMAL K              EXTERNAL
# 35565                  NO DATA     GUNWANTI HARDASMAL K              EXTERNAL
# 35566                  NO DATA   PATRICK WILLIAM DUNCAN              EXTERNAL
#
#       LOB CHANNEL      TYPE
# 0      GB    RTGS  OUTGOING
# 1      GB    RTGS  OUTGOING
# 2      GB    RTGS  OUTGOING
# 3      GB    RTGS  OUTGOING
# 4      GB      TT  OUTGOING
# ...    ..     ...       ...
# 35562  GB     SKN  INCOMING
# 35563  GB     SKN  INCOMING
# 35564  GB     SKN  INCOMING
# 35565  GB     SKN  INCOMING
# 35566  GB     SKN  INCOMING
#
# [35567 rows x 12 columns]

# %%
gpd_data = data.groupby(['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME', 'SENDER/RECIPIENT BANK','LOB','TYPE'])['AMOUNT_TX_IDR'].agg(AMOUNT_TX_IDR = 'sum',TRX='count')

# %%
gpd_data.reset_index(inplace=True)

# %%
gpd_data
# Out:
#      DEBTOR GCIF                       DEBTOR NAME       DEBTOR BANK  \
# 0     G000455626         PERMATA ASRIGRIYA LESTARI  BANK BII MAYBANK
# 1     G000457549              VIVAKARYA WISATAJAYA  BANK BII MAYBANK
# 2     G000466532             CI A HYDROPOWER ABADI  BANK BII MAYBANK
# 3     G000473942                BADE MAKMUR ORISSA  BANK BII MAYBANK
# 4     G000515353                          INDOFICA  BANK BII MAYBANK
# ...          ...                               ...               ...
# 9534     NO DATA            TELEKOMUNIKASI SELULAR  BANK BII MAYBANK
# 9535     NO DATA  TOKIO MARINE LIFE INSURANCE INDO  BANK BII MAYBANK
# 9536     NO DATA              TORABIKA EKA SEMESTA  BANK BII MAYBANK
# 9537     NO DATA              TORABIKA EKA SEMESTA  BANK BII MAYBANK
# 9538     NO DATA         ZURICH ASURANSI INDONESIA  BANK BII MAYBANK
#
#             SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK   LOB      TYPE  \
# 0             BANK RAYA INDONESIA              EXTERNAL    GB  INCOMING
# 1             BANK BJB KC TANGSEL              EXTERNAL    GB  INCOMING
# 2       INDAH KIAT PULP AND PAPER              EXTERNAL  RSME  INCOMING
# 3     ASURANSI JIWA SINARMAS MSIG              EXTERNAL  RSME  OUTGOING
# 4                   ANDAR PRATIWI              EXTERNAL    GB  OUTGOING
# ...                           ...                   ...   ...       ...
# 9534       TELEKOMUNIKASI SELULAR              EXTERNAL    GB  OUTGOING
# 9535     TM USD MONEY MARKET FUND              EXTERNAL    GB  OUTGOING
# 9536         TORABIKA EKA SEMESTA              EXTERNAL    GB  INCOMING
# 9537         TORABIKA EKA SEMESTA              EXTERNAL    GB  OUTGOING
# 9538        ZURICH ASURANSI I USD              EXTERNAL    GB  OUTGOING
#
#       AMOUNT_TX_IDR  TRX
# 0      2.703629e+06    3
# 1      2.047349e+07    3
# 2      7.422500e+06    1
# 3      1.755000e+06    1
# 4      2.319800e+07    1
# ...             ...  ...
# 9534   1.386613e+08    3
# 9535   3.716693e+09    2
# 9536   2.968500e+10    1
# 9537   2.227069e+11    2
# 9538   1.484937e+10    1
#
# [9539 rows x 9 columns]

# %%
gpd_data.to_excel('GB GPD.xlsx', index=False)

# %% [markdown]
# # GPD 2

# %%
data = pd.read_excel(r'C:\Users\MR38804\Documents\Network Graph\GB Request\GB Transactions & Entities Summary 250123.xlsx', sheet_name='Transactions Top Entities Only')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DEBTOR GCIF            92 non-null     object
#  1   DEBTOR NAME            92 non-null     object
#  2   DEBTOR BANK            92 non-null     object
#  3   SENDER/RECIPIENT NAME  92 non-null     object
#  4   SENDER/RECIPIENT BANK  92 non-null     object
#  5   LOB                    92 non-null     object
#  6   TYPE                   92 non-null     object
#  7   AMOUNT_TX_IDR          92 non-null     float64
#  8   TRX                    92 non-null     int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 6.6+ KB

# %%
data.columns
# Out:
# Index(['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME',
#        'SENDER/RECIPIENT BANK', 'LOB', 'TYPE', 'AMOUNT_TX_IDR', 'TRX'],
#       dtype='object')

# %%
data = data[['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME',
       'SENDER/RECIPIENT BANK', 'LOB', 'TYPE', 'AMOUNT_TX_IDR', 'TRX']]

# %%
data_gpd = data.groupby(['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME',
       'SENDER/RECIPIENT BANK', 'LOB', 'TYPE']).agg({'AMOUNT_TX_IDR':'sum','TRX':'sum'})

# %%
data_gpd.reset_index(inplace=True)

# %%
data_gpd
# Out:
#    DEBTOR GCIF                   DEBTOR NAME       DEBTOR BANK  \
# 0   G002973899         KALTIM ARWANA LESTARI  BANK BII MAYBANK
# 1   G004119053  CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK
# 2   G004119053  CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK
# 3   G004119053  CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK
# 4   G004119053  CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK
# ..         ...                           ...               ...
# 85  G902174127             INDONESIA PRATAMA  BANK BII MAYBANK
# 86  G902174127             INDONESIA PRATAMA  BANK BII MAYBANK
# 87  G902174127             INDONESIA PRATAMA  BANK BII MAYBANK
# 88  G902174127             INDONESIA PRATAMA  BANK BII MAYBANK
# 89  G902174127             INDONESIA PRATAMA  BANK BII MAYBANK
#
#          SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK LOB      TYPE  \
# 0         KARUNIA PRIMA MEDIKA              EXTERNAL  GB  OUTGOING
# 1                 AGUS SUSANTO              EXTERNAL  GB  OUTGOING
# 2            ANANG PRASETYO ST              EXTERNAL  GB  OUTGOING
# 3            ANGELIQUE ARYANTO              EXTERNAL  GB  OUTGOING
# 4             BAMBANG SIENTORO              EXTERNAL  GB  OUTGOING
# ..                         ...                   ...  ..       ...
# 85                DAI BACHTIAR              EXTERNAL  GB  OUTGOING
# 86        KARUNIA PRIMA MEDIKA              EXTERNAL  GB  OUTGOING
# 87  MANDIRI HERINDO ADIPERKASA              EXTERNAL  GB  INCOMING
# 88         PRIMACOM INTERBUANA              EXTERNAL  GB  INCOMING
# 89        SURYA NUSANTARA JAYA              EXTERNAL  GB  OUTGOING
#
#     AMOUNT_TX_IDR  TRX
# 0        572100.0    1
# 1       6526092.0    1
# 2      28378304.0    1
# 3     129356404.0    1
# 4     149217712.0    1
# ..            ...  ...
# 85    100000000.0    1
# 86      8169200.0    2
# 87    350221902.0    6
# 88     48900000.0    3
# 89      1315960.0    2
#
# [90 rows x 9 columns]

# %% [markdown]
# # Trans ID, Entity ID

# %%
current_data = data_gpd
# current_data = pd.read_excel(r'C:\Users\MR38804\Documents\Network Graph\GB Request\GB GPD.xlsx', sheet_name='GB GCIF Only')

# %%
list_entity=current_data['DEBTOR NAME'].values.tolist()
list_entity+=current_data['SENDER/RECIPIENT NAME'].values.tolist()
list_entity=pd.DataFrame({
    'ENTITY NAME':list_entity
})
list_entity=list_entity.drop_duplicates(keep='first')

# %%
list_entity
# Out:
#                       ENTITY NAME
# 0           KALTIM ARWANA LESTARI
# 1    CIPTA DIMENSI BAJA NUSANTARA
# 12      TATAMULIA NUSANTARA INDAH
# 22                     TANUR JAYA
# 23      APIKAYU GLYCERIN REFINERY
# ..                            ...
# 167             DUTAFLOW HIDROLIK
# 171                 KHAN YOGA FIT
# 173     ANINDYA WIRAPUTRA KONSULT
# 175                  DAI BACHTIAR
# 178           PRIMACOM INTERBUANA
#
# [81 rows x 1 columns]

# %%
list_entity.loc[list_entity['ENTITY NAME'].str.contains('AVOLON')]
# Out:
# Empty DataFrame
# Columns: [ENTITY NAME]
# Index: []

# %%
entity_DEBTOR=list(set(current_data['DEBTOR NAME']))
all_entity=list_entity['ENTITY NAME'].values.tolist()
sr_entity_data=[]
for name in all_entity:
    placeholder=''
    as_DEBTOR=current_data.loc[current_data['DEBTOR NAME']==name]
    as_other  =current_data.loc[current_data['SENDER/RECIPIENT NAME']==name]
    
    #if in DEBTOR, incoming -> receiver with Maybank bank, outgoing -> sender with Maybank bank
    if len(as_DEBTOR)!=0: #pernah menjadi customer maybank
        if 'INCOMING' in as_DEBTOR['TYPE'].values and 'OUTGOING' in as_DEBTOR['TYPE'].values:
            sr_entity_data.append([name,'Both',as_DEBTOR['DEBTOR BANK'].iloc[0]])
        elif 'INCOMING' in as_DEBTOR['TYPE'].values:
            sr_entity_data.append([name,'Receiver',as_DEBTOR['DEBTOR BANK'].iloc[0]])
        elif 'OUTGOING' in as_DEBTOR['TYPE'].values:
            sr_entity_data.append([name,'Sender',as_DEBTOR['DEBTOR BANK'].iloc[0]])
    
    #if in sender/recipient, incoming -> sender with SR bank name, outgoing -> recipient with SR bank name
    if len(as_other)!=0: #pernah transaksi dgn rek Maybank sebagai nasabah bank lain
        sr_bank_names=list(set(as_other['SENDER/RECIPIENT BANK']))
        for bank in sr_bank_names:
            as_other_bank=as_other.loc[as_other['SENDER/RECIPIENT BANK']==bank]
            if 'INCOMING' in as_other_bank['TYPE'].values and 'OUTGOING' in as_other_bank['TYPE'].values:
                sr_entity_data.append([name,'Both',bank])
            elif 'INCOMING' in as_other_bank['TYPE'].values:
                sr_entity_data.append([name,'Sender',bank])
            elif 'OUTGOING' in as_other_bank['TYPE'].values:
                sr_entity_data.append([name,'Receiver',bank])

sr_entity_df=pd.DataFrame(sr_entity_data,columns=['NAME','DIRECTION','BANK'])
sr_entity_df
# Out:
#                             NAME DIRECTION              BANK
# 0          KALTIM ARWANA LESTARI    Sender  BANK BII MAYBANK
# 1   CIPTA DIMENSI BAJA NUSANTARA    Sender  BANK BII MAYBANK
# 2      TATAMULIA NUSANTARA INDAH    Sender  BANK BII MAYBANK
# 3                     TANUR JAYA    Sender  BANK BII MAYBANK
# 4      APIKAYU GLYCERIN REFINERY      Both  BANK BII MAYBANK
# ..                           ...       ...               ...
# 76             DUTAFLOW HIDROLIK  Receiver          EXTERNAL
# 77                 KHAN YOGA FIT    Sender          EXTERNAL
# 78     ANINDYA WIRAPUTRA KONSULT    Sender          EXTERNAL
# 79                  DAI BACHTIAR  Receiver          EXTERNAL
# 80           PRIMACOM INTERBUANA    Sender          EXTERNAL
#
# [81 rows x 3 columns]

# %%
sr_entity_df.loc[sr_entity_df['NAME'].str.contains('AVOLON')]
# Out:
# Empty DataFrame
# Columns: [NAME, DIRECTION, BANK]
# Index: []

# %%
#merge gcif
gcif_copying=current_data[['DEBTOR NAME','DEBTOR GCIF']]
gcif_copying.columns=['NAME','GCIF']

sr_entity_df=sr_entity_df.merge(gcif_copying,on='NAME',how='left')
sr_entity_df=sr_entity_df.fillna('External')

sr_entity_df=sr_entity_df.drop_duplicates()
sr_entity_df
# Out:
#                              NAME DIRECTION              BANK        GCIF
# 0           KALTIM ARWANA LESTARI    Sender  BANK BII MAYBANK  G002973899
# 1    CIPTA DIMENSI BAJA NUSANTARA    Sender  BANK BII MAYBANK  G004119053
# 12      TATAMULIA NUSANTARA INDAH    Sender  BANK BII MAYBANK  G201151925
# 22                     TANUR JAYA    Sender  BANK BII MAYBANK  G204814982
# 23      APIKAYU GLYCERIN REFINERY      Both  BANK BII MAYBANK  G209092527
# ..                            ...       ...               ...         ...
# 135             DUTAFLOW HIDROLIK  Receiver          EXTERNAL    External
# 136                 KHAN YOGA FIT    Sender          EXTERNAL    External
# 137     ANINDYA WIRAPUTRA KONSULT    Sender          EXTERNAL    External
# 138                  DAI BACHTIAR  Receiver          EXTERNAL    External
# 139           PRIMACOM INTERBUANA    Sender          EXTERNAL    External
#
# [81 rows x 4 columns]

# %%
row=[sr_entity_df.iloc[0]['NAME'],sr_entity_df.iloc[0]['DIRECTION'],sr_entity_df.iloc[0]['BANK']]
'MAYBANK' in row[2]
# Out:
# True

# %%
#'MBI Out','MBI In','MBI Both','Non-MBI Out','Non-MBI In','Non-MBI Both'),
# color=c("#3333ff","#00bf30","orange","#685b5b","#c071f1","#ff0000"))
final_entity_df=[]
for i in range(len(sr_entity_df)):
    row=sr_entity_df.iloc[i]
    row=[row['NAME'],row['DIRECTION'],row['BANK'],row['GCIF']
         #,row['LOB']
        ]
    
    #row color (based on internal/external)
    if 'MAYBANK' in row[2]: #internal
        if row[1]=='Both':
            row+=['MBI Both','orange']
        elif row[1]=='Receiver':
            row+=['MBI In','#00bf30']
        else:
            row+=['MBI Out','#3333ff']
    else:
        if row[1]=='Both':
            row+=['Non-MBI Both','#ff0000']
        elif row[1]=='Receiver':
            row+=['Non-MBI In','#c071f1']
        else:
            row+=['Non-MBI Out','#685b5b']
    
    #row shape (semuanya dot) -> uncomment if needed
    row+=['dot']
    #row shape (tergantung lob) -> uncomment if needed
    #if row[4] == 'Consumer':
    #    row+=['square']
    #elif row[4] == 'RSME':
    #    row+=['triangle']
    #elif row[4] == 'SME+':
    #    row+=['triangleDown']
    #elif row[4] == 'Corporate':
    #    row+=['star']
    #elif row[4] == 'Commercial (BB)':
    #    row+=['diamond']
    #else :
    #    row+=['dot']

    
    #row id (tambahin i)
    row+=[i]
    
    #append
    final_entity_df.append(row)
    
final_entity_df=pd.DataFrame(final_entity_df,
                             columns=['ENTITY','DIRECTION','SOURCE','GCIF',
                                      #'LOB',
                                      'TYPE','COLOR','SHAPE','ID'])
final_entity_df=final_entity_df.drop_duplicates()
final_entity_df
# Out:
#                           ENTITY DIRECTION            SOURCE        GCIF  \
# 0          KALTIM ARWANA LESTARI    Sender  BANK BII MAYBANK  G002973899
# 1   CIPTA DIMENSI BAJA NUSANTARA    Sender  BANK BII MAYBANK  G004119053
# 2      TATAMULIA NUSANTARA INDAH    Sender  BANK BII MAYBANK  G201151925
# 3                     TANUR JAYA    Sender  BANK BII MAYBANK  G204814982
# 4      APIKAYU GLYCERIN REFINERY      Both  BANK BII MAYBANK  G209092527
# ..                           ...       ...               ...         ...
# 76             DUTAFLOW HIDROLIK  Receiver          EXTERNAL    External
# 77                 KHAN YOGA FIT    Sender          EXTERNAL    External
# 78     ANINDYA WIRAPUTRA KONSULT    Sender          EXTERNAL    External
# 79                  DAI BACHTIAR  Receiver          EXTERNAL    External
# 80           PRIMACOM INTERBUANA    Sender          EXTERNAL    External
#
#            TYPE    COLOR SHAPE  ID
# 0       MBI Out  #3333ff   dot   0
# 1       MBI Out  #3333ff   dot   1
# 2       MBI Out  #3333ff   dot   2
# 3       MBI Out  #3333ff   dot   3
# 4      MBI Both   orange   dot   4
# ..          ...      ...   ...  ..
# 76   Non-MBI In  #c071f1   dot  76
# 77  Non-MBI Out  #685b5b   dot  77
# 78  Non-MBI Out  #685b5b   dot  78
# 79   Non-MBI In  #c071f1   dot  79
# 80  Non-MBI Out  #685b5b   dot  80
#
# [81 rows x 8 columns]

# %%
final_entity_df.loc[final_entity_df['ENTITY'].str.contains('GATEWAY CONTAINER LINE')]
# Out:
# Empty DataFrame
# Columns: [ENTITY, DIRECTION, SOURCE, GCIF, TYPE, COLOR, SHAPE, ID]
# Index: []

# %%
trans_id=[]
for i in range(len(current_data)):
    row=current_data.iloc[i]
    
    if row['TYPE']=='INCOMING': #DEBTOR nerima, sr ngirim
        trans_id.append([row['SENDER/RECIPIENT NAME'],row['SENDER/RECIPIENT BANK'],
                         row['DEBTOR NAME'],row['DEBTOR BANK'],
                         row['AMOUNT_TX_IDR'],row['TRX']])
    else: #DEBTOR ngirim, sr nerima
        trans_id.append([row['DEBTOR NAME'],row['DEBTOR BANK'],
                         row['SENDER/RECIPIENT NAME'],row['SENDER/RECIPIENT BANK'],
                         row['AMOUNT_TX_IDR'],row['TRX']])
    
#create trans_df
trans_id=pd.DataFrame(trans_id,columns=['FROM_ENTITY','FROM_SOURCE','TO_ENTITY','TO_SOURCE','AMOUNT_TX_IDR','TRX'])

#get FROM_ID using entity data
temp=final_entity_df[['ENTITY','SOURCE','ID']].copy()
temp.columns=['FROM_ENTITY','FROM_SOURCE','FROM_ID']
trans_id=trans_id.merge(temp,on=['FROM_ENTITY','FROM_SOURCE'],how='left')

#get TO_ID using entity data
temp=final_entity_df[['ENTITY','SOURCE','ID']].copy()
temp.columns=['TO_ENTITY','TO_SOURCE','TO_ID']
trans_id=trans_id.merge(temp,on=['TO_ENTITY','TO_SOURCE'],how='left')

#trans_id=trans_id[['FROM_ID','TO_ID','AMOUNT_TX_IDR']]
trans_id=trans_id.drop_duplicates()
trans_id
# Out:
#                      FROM_ENTITY       FROM_SOURCE             TO_ENTITY  \
# 0          KALTIM ARWANA LESTARI  BANK BII MAYBANK  KARUNIA PRIMA MEDIKA
# 1   CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK          AGUS SUSANTO
# 2   CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK     ANANG PRASETYO ST
# 3   CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK     ANGELIQUE ARYANTO
# 4   CIPTA DIMENSI BAJA NUSANTARA  BANK BII MAYBANK      BAMBANG SIENTORO
# ..                           ...               ...                   ...
# 85             INDONESIA PRATAMA  BANK BII MAYBANK          DAI BACHTIAR
# 86             INDONESIA PRATAMA  BANK BII MAYBANK  KARUNIA PRIMA MEDIKA
# 87    MANDIRI HERINDO ADIPERKASA          EXTERNAL     INDONESIA PRATAMA
# 88           PRIMACOM INTERBUANA          EXTERNAL     INDONESIA PRATAMA
# 89             INDONESIA PRATAMA  BANK BII MAYBANK  SURYA NUSANTARA JAYA
#
#            TO_SOURCE  AMOUNT_TX_IDR  TRX  FROM_ID  TO_ID
# 0           EXTERNAL       572100.0    1        0     31
# 1           EXTERNAL      6526092.0    1        1     32
# 2           EXTERNAL     28378304.0    1        1     33
# 3           EXTERNAL    129356404.0    1        1     34
# 4           EXTERNAL    149217712.0    1        1     35
# ..               ...            ...  ...      ...    ...
# 85          EXTERNAL    100000000.0    1       30     79
# 86          EXTERNAL      8169200.0    2       30     31
# 87  BANK BII MAYBANK    350221902.0    6       55     30
# 88  BANK BII MAYBANK     48900000.0    3       80     30
# 89          EXTERNAL      1315960.0    2       30     56
#
# [90 rows x 8 columns]

# %%
#create initial size
size_amount=[]
size_count=[]
size_chain=[]
for name in final_entity_df['ID'].values:
    curr_agg=trans_id.loc[(trans_id['FROM_ID']==name)|(trans_id['TO_ID']==name)]
    size_amount.append(sum(curr_agg['AMOUNT_TX_IDR']))
    size_count.append(sum(curr_agg['TRX']))
    size_chain.append(len(curr_agg))

final_entity_df['ORIG_AMOUNT']=size_amount
final_entity_df['ORIG_COUNT']=size_count
final_entity_df['ORIG_CHAIN']=size_chain

final_entity_df['SIZE_AMOUNT']=[1 if i<=1 else i for i in size_amount]
final_entity_df['SIZE_COUNT']=[1 if i<=1 else i for i in size_count]
final_entity_df['SIZE_CHAIN']=[1 if i<=1 else i for i in size_chain]

#create individual flags
final_entity_df['FLAG_AMT']=final_entity_df['SIZE_AMOUNT'].apply(lambda x: 'high amt' if x>=34 else 'low amt')
final_entity_df['FLAG_TRX']=final_entity_df['SIZE_COUNT'].apply(lambda x: 'high freq' if x>=4 else 'low freq')
final_entity_df['FLAG_CHAIN']=final_entity_df['SIZE_CHAIN'].apply(lambda x: 'high chain' if x>=10 else 'low chain')

#create final filter
final_filter=[]
simplified=[]
for i in range(len(final_entity_df)):
    row=final_entity_df.iloc[i]
    curr_filter=''
    
    #final filter
    if row['FLAG_AMT']=='high amt':
        curr_filter+='high amt, '
    if row['FLAG_TRX']=='high freq':
        curr_filter+='high freq, '
    if row['FLAG_CHAIN']=='high chain':
        curr_filter+='high chain, '
    if curr_filter=='':
        curr_filter='low, '
    
    #simplified view
    if row['SIZE_CHAIN']>=2:
        curr_filter+='full'
        simplified.append('full')
    else:
        simplified.append('full')
        
    #remove trailing comma and whitespace
    curr_filter=curr_filter.rstrip(' ')
    curr_filter=curr_filter.rstrip(',')
    
    #append
    final_filter.append(curr_filter+'')

final_entity_df['FILTER']=final_filter
final_entity_df['SIMPLIFIED']=simplified
#final_entity_df['FLAG_LOB']=final_entity_df['LOB']+', '+final_entity_df['SIMPLIFIED']

# %%
final_entity_df
# Out:
#                           ENTITY DIRECTION            SOURCE        GCIF  \
# 0          KALTIM ARWANA LESTARI    Sender  BANK BII MAYBANK  G002973899
# 1   CIPTA DIMENSI BAJA NUSANTARA    Sender  BANK BII MAYBANK  G004119053
# 2      TATAMULIA NUSANTARA INDAH    Sender  BANK BII MAYBANK  G201151925
# 3                     TANUR JAYA    Sender  BANK BII MAYBANK  G204814982
# 4      APIKAYU GLYCERIN REFINERY      Both  BANK BII MAYBANK  G209092527
# ..                           ...       ...               ...         ...
# 76             DUTAFLOW HIDROLIK  Receiver          EXTERNAL    External
# 77                 KHAN YOGA FIT    Sender          EXTERNAL    External
# 78     ANINDYA WIRAPUTRA KONSULT    Sender          EXTERNAL    External
# 79                  DAI BACHTIAR  Receiver          EXTERNAL    External
# 80           PRIMACOM INTERBUANA    Sender          EXTERNAL    External
#
#            TYPE    COLOR SHAPE  ID   ORIG_AMOUNT  ORIG_COUNT  ORIG_CHAIN  \
# 0       MBI Out  #3333ff   dot   0  5.721000e+05           1           1
# 1       MBI Out  #3333ff   dot   1  4.165483e+08          13          11
# 2       MBI Out  #3333ff   dot   2  4.130530e+08          11          10
# 3       MBI Out  #3333ff   dot   3  6.221000e+05           1           1
# 4      MBI Both   orange   dot   4  4.049510e+09           5           2
# ..          ...      ...   ...  ..           ...         ...         ...
# 76   Non-MBI In  #c071f1   dot  76  6.606846e+07           1           1
# 77  Non-MBI Out  #685b5b   dot  77  7.970087e+07           7           1
# 78  Non-MBI Out  #685b5b   dot  78  8.104460e+08           5           1
# 79   Non-MBI In  #c071f1   dot  79  1.000000e+08           1           1
# 80  Non-MBI Out  #685b5b   dot  80  4.890000e+07           3           1
#
#      SIZE_AMOUNT  SIZE_COUNT  SIZE_CHAIN  FLAG_AMT   FLAG_TRX  FLAG_CHAIN  \
# 0   5.721000e+05           1           1  high amt   low freq   low chain
# 1   4.165483e+08          13          11  high amt  high freq  high chain
# 2   4.130530e+08          11          10  high amt  high freq  high chain
# 3   6.221000e+05           1           1  high amt   low freq   low chain
# 4   4.049510e+09           5           2  high amt  high freq   low chain
# ..           ...         ...         ...       ...        ...         ...
# 76  6.606846e+07           1           1  high amt   low freq   low chain
# 77  7.970087e+07           7           1  high amt  high freq   low chain
# 78  8.104460e+08           5           1  high amt  high freq   low chain
# 79  1.000000e+08           1           1  high amt   low freq   low chain
# 80  4.890000e+07           3           1  high amt   low freq   low chain
#
#                                    FILTER SIMPLIFIED
# 0                                high amt       full
# 1   high amt, high freq, high chain, full       full
# 2   high amt, high freq, high chain, full       full
# 3                                high amt       full
# 4               high amt, high freq, full       full
# ..                                    ...        ...
# 76                               high amt       full
# 77                    high amt, high freq       full
# 78                    high amt, high freq       full
# 79                               high amt       full
# 80                               high amt       full
#
# [81 rows x 19 columns]

# %%
final_entity_df.to_csv('GB Top_entity_id.csv')
trans_id.to_csv('GB Top_trans_id.csv')
