# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r'C:\Users\MR38804\Documents\Network Graph\SME+ Request\GPD 2212 SME+.xlsx', sheet_name='Top 50 Transactions')

# %%
data
# Out:
#                   BASE DATE        GCIF  CIF        AMOUNT  ORIGIN ACCT NO  \
# 0       2022-08-03 00:00:00  G000456624  NaN  1.425000e+09    2.016302e+09
# 1       2022-08-11 00:00:00  G000640193  NaN  1.000000e+09    2.006029e+09
# 2       2022-08-15 00:00:00  G000679126  NaN  5.880000e+06    1.610049e+11
# 3       2022-08-15 00:00:00  G000679126  NaN  1.965000e+06    1.610049e+11
# 4       2022-08-15 00:00:00  G000679126  NaN  1.965000e+06    1.620040e+11
# ...                     ...         ...  ...           ...             ...
# 191311                  NaN  G505093435  NaN  2.675720e+08             NaN
# 191312                  NaN  G209417484  NaN  6.100119e+09             NaN
# 191313                  NaN  G007262892  NaN  2.541986e+08             NaN
# 191314                  NaN  G007262892  NaN  2.702570e+08             NaN
# 191315                  NaN  G009025529  NaN  3.533640e+07             NaN
#
#                       ORIGIN NAME                  ORIGIN BANK  \
# 0        SUMMARECON AGUNG TBK, PT             BANK BII MAYBANK
# 1                 SURAPANDANG, PT             BANK BII MAYBANK
# 2                         BUDIMAN             BANK BII MAYBANK
# 3                         BUDIMAN             BANK BII MAYBANK
# 4                         BUDIMAN             BANK BII MAYBANK
# ...                           ...                          ...
# 191311      ZANMEI TRAVEL LIMITED                HSBC BANK USA
# 191312        ZEAL TRADING FZ LLC                 CITIBANK N.A
# 191313    ZOMEL MARKETING SDN BHD    JPMORGAN CHASE BANK, N.A.
# 191314  ZOMEL MARKETING SDN. BHD.    JPMORGAN CHASE BANK, N.A.
# 191315      ZUTTORIDE CORPORATION  CITIBANK N.A., TOKYO BRANCH
#
#        BENEFICIARY ACCT NO                     BENEFICIARY NAME  \
# 0               0701427009                  PT SUMMARECON AGUNG
# 1               2066770998           PT SWALLOW GLOBE INDONESIA
# 2             162003012060                                  NaN
# 3                        0                                  NaN
# 4                        0                                  NaN
# ...                    ...                                  ...
# 191311                 NaN             PT  MITRA GLOBAL HOLIDAY
# 191312                 NaN  PT LANDASAN SURYA TEKNIK MUTIARA TA
# 191313                 NaN                    PT. MANOHARA ASRI
# 191314                 NaN                     PT.MANOHARA ASRI
# 191315                 NaN   PT.LOGIQUE DIGITAL INDONESIA GD AD
#
#         BENEFICIARY BANK   LoB               REGION FUNDING/LENDING TRX TYPE  \
# 0           PERMATA BANK    BB            JAKARTA 2         Funding     RTGS
# 1               BANK BCA    BB       SULAWESI & IBT         Lending     RTGS
# 2       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# 3       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# 4       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# ...                  ...   ...                  ...             ...      ...
# 191311  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
# 191312  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
# 191313  BANK BII MAYBANK    BB  JATIM, BALI & NUSRA         Lending       TT
# 191314  BANK BII MAYBANK    BB  JATIM, BALI & NUSRA         Lending       TT
# 191315  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
#
#           IN/OUT  Unnamed: 15
# 0       OUTGOING          NaN
# 1       OUTGOING          NaN
# 2       OUTGOING          NaN
# 3       OUTGOING          NaN
# 4       OUTGOING          NaN
# ...          ...          ...
# 191311  INCOMING          NaN
# 191312  INCOMING          NaN
# 191313  INCOMING          NaN
# 191314  INCOMING          NaN
# 191315  INCOMING          NaN
#
# [191316 rows x 16 columns]

# %%
data.drop(['BASE DATE', 'Unnamed: 15'], inplace=True, axis=1)

# %%
data
# Out:
#               GCIF  CIF        AMOUNT  ORIGIN ACCT NO  \
# 0       G000456624  NaN  1.425000e+09    2.016302e+09
# 1       G000640193  NaN  1.000000e+09    2.006029e+09
# 2       G000679126  NaN  5.880000e+06    1.610049e+11
# 3       G000679126  NaN  1.965000e+06    1.610049e+11
# 4       G000679126  NaN  1.965000e+06    1.620040e+11
# ...            ...  ...           ...             ...
# 191311  G505093435  NaN  2.675720e+08             NaN
# 191312  G209417484  NaN  6.100119e+09             NaN
# 191313  G007262892  NaN  2.541986e+08             NaN
# 191314  G007262892  NaN  2.702570e+08             NaN
# 191315  G009025529  NaN  3.533640e+07             NaN
#
#                       ORIGIN NAME                  ORIGIN BANK  \
# 0        SUMMARECON AGUNG TBK, PT             BANK BII MAYBANK
# 1                 SURAPANDANG, PT             BANK BII MAYBANK
# 2                         BUDIMAN             BANK BII MAYBANK
# 3                         BUDIMAN             BANK BII MAYBANK
# 4                         BUDIMAN             BANK BII MAYBANK
# ...                           ...                          ...
# 191311      ZANMEI TRAVEL LIMITED                HSBC BANK USA
# 191312        ZEAL TRADING FZ LLC                 CITIBANK N.A
# 191313    ZOMEL MARKETING SDN BHD    JPMORGAN CHASE BANK, N.A.
# 191314  ZOMEL MARKETING SDN. BHD.    JPMORGAN CHASE BANK, N.A.
# 191315      ZUTTORIDE CORPORATION  CITIBANK N.A., TOKYO BRANCH
#
#        BENEFICIARY ACCT NO                     BENEFICIARY NAME  \
# 0               0701427009                  PT SUMMARECON AGUNG
# 1               2066770998           PT SWALLOW GLOBE INDONESIA
# 2             162003012060                                  NaN
# 3                        0                                  NaN
# 4                        0                                  NaN
# ...                    ...                                  ...
# 191311                 NaN             PT  MITRA GLOBAL HOLIDAY
# 191312                 NaN  PT LANDASAN SURYA TEKNIK MUTIARA TA
# 191313                 NaN                    PT. MANOHARA ASRI
# 191314                 NaN                     PT.MANOHARA ASRI
# 191315                 NaN   PT.LOGIQUE DIGITAL INDONESIA GD AD
#
#         BENEFICIARY BANK   LoB               REGION FUNDING/LENDING TRX TYPE  \
# 0           PERMATA BANK    BB            JAKARTA 2         Funding     RTGS
# 1               BANK BCA    BB       SULAWESI & IBT         Lending     RTGS
# 2       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# 3       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# 4       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# ...                  ...   ...                  ...             ...      ...
# 191311  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
# 191312  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
# 191313  BANK BII MAYBANK    BB  JATIM, BALI & NUSRA         Lending       TT
# 191314  BANK BII MAYBANK    BB  JATIM, BALI & NUSRA         Lending       TT
# 191315  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
#
#           IN/OUT
# 0       OUTGOING
# 1       OUTGOING
# 2       OUTGOING
# 3       OUTGOING
# 4       OUTGOING
# ...          ...
# 191311  INCOMING
# 191312  INCOMING
# 191313  INCOMING
# 191314  INCOMING
# 191315  INCOMING
#
# [191316 rows x 14 columns]

# %%
#cleanse name values - origin name
data['ORIGIN NAME']=data['ORIGIN NAME'].str.upper()
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('PT',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('TBK',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('.',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('-',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace(',',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace("''"," ")
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('//',' ')
data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('\s+',' ',regex=True)
data['ORIGIN NAME']=data['ORIGIN NAME'].str.strip()
# Out:
# <ipython-input-6-a20c479fbe60>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['ORIGIN NAME']=data['ORIGIN NAME'].str.replace('.',' ')

# %%
#cleanse name values - benficiary name
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.upper()
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('PT',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('TBK',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('.',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('-',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace(',',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace("''"," ")
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('//',' ')
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('\s+',' ',regex=True)
data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.strip()
# Out:
# <ipython-input-7-f370484ed1e1>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['BENEFICIARY NAME']=data['BENEFICIARY NAME'].str.replace('.',' ')

# %%
data
# Out:
#               GCIF  CIF        AMOUNT  ORIGIN ACCT NO  \
# 0       G000456624  NaN  1.425000e+09    2.016302e+09
# 1       G000640193  NaN  1.000000e+09    2.006029e+09
# 2       G000679126  NaN  5.880000e+06    1.610049e+11
# 3       G000679126  NaN  1.965000e+06    1.610049e+11
# 4       G000679126  NaN  1.965000e+06    1.620040e+11
# ...            ...  ...           ...             ...
# 191311  G505093435  NaN  2.675720e+08             NaN
# 191312  G209417484  NaN  6.100119e+09             NaN
# 191313  G007262892  NaN  2.541986e+08             NaN
# 191314  G007262892  NaN  2.702570e+08             NaN
# 191315  G009025529  NaN  3.533640e+07             NaN
#
#                     ORIGIN NAME                  ORIGIN BANK  \
# 0              SUMMARECON AGUNG             BANK BII MAYBANK
# 1                   SURAPANDANG             BANK BII MAYBANK
# 2                       BUDIMAN             BANK BII MAYBANK
# 3                       BUDIMAN             BANK BII MAYBANK
# 4                       BUDIMAN             BANK BII MAYBANK
# ...                         ...                          ...
# 191311    ZANMEI TRAVEL LIMITED                HSBC BANK USA
# 191312      ZEAL TRADING FZ LLC                 CITIBANK N.A
# 191313  ZOMEL MARKETING SDN BHD    JPMORGAN CHASE BANK, N.A.
# 191314  ZOMEL MARKETING SDN BHD    JPMORGAN CHASE BANK, N.A.
# 191315    ZUTTORIDE CORPORATION  CITIBANK N.A., TOKYO BRANCH
#
#        BENEFICIARY ACCT NO                  BENEFICIARY NAME  \
# 0               0701427009                  SUMMARECON AGUNG
# 1               2066770998           SWALLOW GLOBE INDONESIA
# 2             162003012060                               NaN
# 3                        0                               NaN
# 4                        0                               NaN
# ...                    ...                               ...
# 191311                 NaN              MITRA GLOBAL HOLIDAY
# 191312                 NaN  LANDASAN SURYA TEKNIK MUTIARA TA
# 191313                 NaN                     MANOHARA ASRI
# 191314                 NaN                     MANOHARA ASRI
# 191315                 NaN   LOGIQUE DIGITAL INDONESIA GD AD
#
#         BENEFICIARY BANK   LoB               REGION FUNDING/LENDING TRX TYPE  \
# 0           PERMATA BANK    BB            JAKARTA 2         Funding     RTGS
# 1               BANK BCA    BB       SULAWESI & IBT         Lending     RTGS
# 2       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# 3       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# 4       BANK BII MAYBANK  RSME                  ALL            Both      M2U
# ...                  ...   ...                  ...             ...      ...
# 191311  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
# 191312  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
# 191313  BANK BII MAYBANK    BB  JATIM, BALI & NUSRA         Lending       TT
# 191314  BANK BII MAYBANK    BB  JATIM, BALI & NUSRA         Lending       TT
# 191315  BANK BII MAYBANK    BB            JAKARTA 1         Funding       TT
#
#           IN/OUT
# 0       OUTGOING
# 1       OUTGOING
# 2       OUTGOING
# 3       OUTGOING
# 4       OUTGOING
# ...          ...
# 191311  INCOMING
# 191312  INCOMING
# 191313  INCOMING
# 191314  INCOMING
# 191315  INCOMING
#
# [191316 rows x 14 columns]

# %%
dataInc = data[data['IN/OUT']=='INCOMING']
dataInc.columns = ['DEBTOR GCIF', 'DEBTOR CIF', 'AMOUNT_TX_IDR', 'SENDER/RECIPIENT ACCOUNT', 
'SENDER/RECIPIENT NAME', 'SENDER/RECIPIENT BANK', 'DEBTOR ACCOUNT', 'DEBTOR NAME', 'DEBTOR BANK',
'LOB', 'REGION' , 'FUNDING/LENDING', 'CHANNEL','TYPE']

# %%
dataInc
# Out:
#        DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR  SENDER/RECIPIENT ACCOUNT  \
# 53210   G609358825         NaN   2.141600e+07                       NaN
# 53211   G309595312         NaN   7.489950e+08                       NaN
# 53212   G002911824         NaN   4.448965e+08                       NaN
# 53213   G002911824         NaN   2.689194e+08                       NaN
# 53214   G407379957         NaN   1.632675e+07                       NaN
# ...            ...         ...            ...                       ...
# 191311  G505093435         NaN   2.675720e+08                       NaN
# 191312  G209417484         NaN   6.100119e+09                       NaN
# 191313  G007262892         NaN   2.541986e+08                       NaN
# 191314  G007262892         NaN   2.702570e+08                       NaN
# 191315  G009025529         NaN   3.533640e+07                       NaN
#
#                   SENDER/RECIPIENT NAME        SENDER/RECIPIENT BANK  \
# 53210           0 FIELDS FACTORY CO LTD  CITIBANK N.A., TOKYO BRANCH
# 53211                   888 PAPER E LTD    JPMORGAN CHASE BANK, N.A.
# 53212   ABDULMAJED ABDULWASE SAIF GROUP    JPMORGAN CHASE BANK, N.A.
# 53213   ABDULMAJED ABDULWASE SAIF GROUP                 CITIBANK N.A
# 53214           ADI INTI MANDIRI SOLUSI                     BANK BCA
# ...                                 ...                          ...
# 191311            ZANMEI TRAVEL LIMITED                HSBC BANK USA
# 191312              ZEAL TRADING FZ LLC                 CITIBANK N.A
# 191313          ZOMEL MARKETING SDN BHD    JPMORGAN CHASE BANK, N.A.
# 191314          ZOMEL MARKETING SDN BHD    JPMORGAN CHASE BANK, N.A.
# 191315            ZUTTORIDE CORPORATION  CITIBANK N.A., TOKYO BRANCH
#
#        DEBTOR ACCOUNT                       DEBTOR NAME       DEBTOR BANK  \
# 53210             NaN          10 FIELDS FACTORY CO LTD  BANK BII MAYBANK
# 53211             NaN               CV PUTRA UTAMA JAYA  BANK BII MAYBANK
# 53212             NaN             POLA MANUNGGAL SEJATI  BANK BII MAYBANK
# 53213             NaN             POLA MANUNGGAL SEJATI  BANK BII MAYBANK
# 53214             NaN           ADI INTI MANDIRI SOLUSI  BANK BII MAYBANK
# ...               ...                               ...               ...
# 191311            NaN              MITRA GLOBAL HOLIDAY  BANK BII MAYBANK
# 191312            NaN  LANDASAN SURYA TEKNIK MUTIARA TA  BANK BII MAYBANK
# 191313            NaN                     MANOHARA ASRI  BANK BII MAYBANK
# 191314            NaN                     MANOHARA ASRI  BANK BII MAYBANK
# 191315            NaN   LOGIQUE DIGITAL INDONESIA GD AD  BANK BII MAYBANK
#
#          LOB               REGION FUNDING/LENDING CHANNEL      TYPE
# 53210     BB            JAKARTA 1         Funding      TT  INCOMING
# 53211     BB            JAKARTA 3         Funding      TT  INCOMING
# 53212     BB           JAWA BARAT         Lending      TT  INCOMING
# 53213     BB           JAWA BARAT         Lending      TT  INCOMING
# 53214   RSME                  ALL            Both      TT  INCOMING
# ...      ...                  ...             ...     ...       ...
# 191311    BB            JAKARTA 1         Funding      TT  INCOMING
# 191312    BB            JAKARTA 1         Funding      TT  INCOMING
# 191313    BB  JATIM, BALI & NUSRA         Lending      TT  INCOMING
# 191314    BB  JATIM, BALI & NUSRA         Lending      TT  INCOMING
# 191315    BB            JAKARTA 1         Funding      TT  INCOMING
#
# [117487 rows x 14 columns]

# %%
dataOut = data[data['IN/OUT']=='OUTGOING']
dataOut.columns = ['DEBTOR GCIF', 'DEBTOR CIF', 'AMOUNT_TX_IDR', 'DEBTOR ACCOUNT', 'DEBTOR NAME', 
'DEBTOR BANK', 'SENDER/RECIPIENT ACCOUNT', 'SENDER/RECIPIENT NAME', 'SENDER/RECIPIENT BANK', 'LOB',
'REGION', 'FUNDING/LENDING', 'CHANNEL', 'TYPE']

# %%
dataOut
# Out:
#        DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR  DEBTOR ACCOUNT  \
# 0       G000456624         NaN   1.425000e+09    2.016302e+09
# 1       G000640193         NaN   1.000000e+09    2.006029e+09
# 2       G000679126         NaN   5.880000e+06    1.610049e+11
# 3       G000679126         NaN   1.965000e+06    1.610049e+11
# 4       G000679126         NaN   1.965000e+06    1.620040e+11
# ...            ...         ...            ...             ...
# 191303  G300928207         NaN   8.267272e+08             NaN
# 191304  G300928207         NaN   8.311800e+07             NaN
# 191305  G109003277         NaN   3.212400e+07             NaN
# 191306  G109003277         NaN   1.606200e+07             NaN
# 191307  G109003277         NaN   7.286366e+07             NaN
#
#                 DEBTOR NAME       DEBTOR BANK SENDER/RECIPIENT ACCOUNT  \
# 0          SUMMARECON AGUNG  BANK BII MAYBANK               0701427009
# 1               SURAPANDANG  BANK BII MAYBANK               2066770998
# 2                   BUDIMAN  BANK BII MAYBANK             162003012060
# 3                   BUDIMAN  BANK BII MAYBANK                        0
# 4                   BUDIMAN  BANK BII MAYBANK                        0
# ...                     ...               ...                      ...
# 191303  YORKSHIRE INDONESIA  BANK BII MAYBANK                      NaN
# 191304  YORKSHIRE INDONESIA  BANK BII MAYBANK                      NaN
# 191305  YOSHIWADA INDONESIA  BANK BII MAYBANK                      NaN
# 191306  YOSHIWADA INDONESIA  BANK BII MAYBANK                      NaN
# 191307  YOSHIWADA INDONESIA  BANK BII MAYBANK                      NaN
#
#                 SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK   LOB  \
# 0                    SUMMARECON AGUNG          PERMATA BANK    BB
# 1             SWALLOW GLOBE INDONESIA              BANK BCA    BB
# 2                                 NaN      BANK BII MAYBANK  RSME
# 3                                 NaN      BANK BII MAYBANK  RSME
# 4                                 NaN      BANK BII MAYBANK  RSME
# ...                               ...                   ...   ...
# 191303  RICH CHEMICALS GROUP HONGKONG              CITIBANK    BB
# 191304          SAMBANG ENTERPRISE CO              CITIBANK    BB
# 191305                     KGK CO LTD      STANCHART, TOKYO    BB
# 191306              MASAHIRO NAGAFUJI      STANCHART, TOKYO    BB
# 191307     YOSHIWADA HAMAMATSU CO LTD      STANCHART, TOKYO    BB
#
#                 REGION FUNDING/LENDING CHANNEL      TYPE
# 0            JAKARTA 2         Funding    RTGS  OUTGOING
# 1       SULAWESI & IBT         Lending    RTGS  OUTGOING
# 2                  ALL            Both     M2U  OUTGOING
# 3                  ALL            Both     M2U  OUTGOING
# 4                  ALL            Both     M2U  OUTGOING
# ...                ...             ...     ...       ...
# 191303      JAWA BARAT         Funding      TT  OUTGOING
# 191304      JAWA BARAT         Funding      TT  OUTGOING
# 191305       JAKARTA 3         Funding      TT  OUTGOING
# 191306       JAKARTA 3         Funding      TT  OUTGOING
# 191307       JAKARTA 3         Funding      TT  OUTGOING
#
# [73829 rows x 14 columns]

# %%
data = pd.concat([dataOut, dataInc])

# %%
data['DEBTOR BANK'].value_counts()
# Out:
# BANK BII MAYBANK    191316
# Name: DEBTOR BANK, dtype: int64

# %%
data
# Out:
#        DEBTOR GCIF  DEBTOR CIF  AMOUNT_TX_IDR  DEBTOR ACCOUNT  \
# 0       G000456624         NaN   1.425000e+09    2016301778.0
# 1       G000640193         NaN   1.000000e+09    2006028862.0
# 2       G000679126         NaN   5.880000e+06  161004876356.0
# 3       G000679126         NaN   1.965000e+06  161004876356.0
# 4       G000679126         NaN   1.965000e+06  162004013525.0
# ...            ...         ...            ...             ...
# 191311  G505093435         NaN   2.675720e+08             NaN
# 191312  G209417484         NaN   6.100119e+09             NaN
# 191313  G007262892         NaN   2.541986e+08             NaN
# 191314  G007262892         NaN   2.702570e+08             NaN
# 191315  G009025529         NaN   3.533640e+07             NaN
#
#                              DEBTOR NAME       DEBTOR BANK  \
# 0                       SUMMARECON AGUNG  BANK BII MAYBANK
# 1                            SURAPANDANG  BANK BII MAYBANK
# 2                                BUDIMAN  BANK BII MAYBANK
# 3                                BUDIMAN  BANK BII MAYBANK
# 4                                BUDIMAN  BANK BII MAYBANK
# ...                                  ...               ...
# 191311              MITRA GLOBAL HOLIDAY  BANK BII MAYBANK
# 191312  LANDASAN SURYA TEKNIK MUTIARA TA  BANK BII MAYBANK
# 191313                     MANOHARA ASRI  BANK BII MAYBANK
# 191314                     MANOHARA ASRI  BANK BII MAYBANK
# 191315   LOGIQUE DIGITAL INDONESIA GD AD  BANK BII MAYBANK
#
#        SENDER/RECIPIENT ACCOUNT    SENDER/RECIPIENT NAME  \
# 0                    0701427009         SUMMARECON AGUNG
# 1                    2066770998  SWALLOW GLOBE INDONESIA
# 2                  162003012060                      NaN
# 3                             0                      NaN
# 4                             0                      NaN
# ...                         ...                      ...
# 191311                      NaN    ZANMEI TRAVEL LIMITED
# 191312                      NaN      ZEAL TRADING FZ LLC
# 191313                      NaN  ZOMEL MARKETING SDN BHD
# 191314                      NaN  ZOMEL MARKETING SDN BHD
# 191315                      NaN    ZUTTORIDE CORPORATION
#
#               SENDER/RECIPIENT BANK   LOB               REGION  \
# 0                      PERMATA BANK    BB            JAKARTA 2
# 1                          BANK BCA    BB       SULAWESI & IBT
# 2                  BANK BII MAYBANK  RSME                  ALL
# 3                  BANK BII MAYBANK  RSME                  ALL
# 4                  BANK BII MAYBANK  RSME                  ALL
# ...                             ...   ...                  ...
# 191311                HSBC BANK USA    BB            JAKARTA 1
# 191312                 CITIBANK N.A    BB            JAKARTA 1
# 191313    JPMORGAN CHASE BANK, N.A.    BB  JATIM, BALI & NUSRA
# 191314    JPMORGAN CHASE BANK, N.A.    BB  JATIM, BALI & NUSRA
# 191315  CITIBANK N.A., TOKYO BRANCH    BB            JAKARTA 1
#
#        FUNDING/LENDING CHANNEL      TYPE
# 0              Funding    RTGS  OUTGOING
# 1              Lending    RTGS  OUTGOING
# 2                 Both     M2U  OUTGOING
# 3                 Both     M2U  OUTGOING
# 4                 Both     M2U  OUTGOING
# ...                ...     ...       ...
# 191311         Funding      TT  INCOMING
# 191312         Funding      TT  INCOMING
# 191313         Lending      TT  INCOMING
# 191314         Lending      TT  INCOMING
# 191315         Funding      TT  INCOMING
#
# [191316 rows x 14 columns]

# %%
data['SENDER/RECIPIENT BANK']='EXTERNAL'

# %%
data.fillna('NO DATA', inplace=True)

# %%
data
# Out:
#        DEBTOR GCIF DEBTOR CIF  AMOUNT_TX_IDR  DEBTOR ACCOUNT  \
# 0       G000456624    NO DATA   1.425000e+09    2016301778.0
# 1       G000640193    NO DATA   1.000000e+09    2006028862.0
# 2       G000679126    NO DATA   5.880000e+06  161004876356.0
# 3       G000679126    NO DATA   1.965000e+06  161004876356.0
# 4       G000679126    NO DATA   1.965000e+06  162004013525.0
# ...            ...        ...            ...             ...
# 191311  G505093435    NO DATA   2.675720e+08         NO DATA
# 191312  G209417484    NO DATA   6.100119e+09         NO DATA
# 191313  G007262892    NO DATA   2.541986e+08         NO DATA
# 191314  G007262892    NO DATA   2.702570e+08         NO DATA
# 191315  G009025529    NO DATA   3.533640e+07         NO DATA
#
#                              DEBTOR NAME       DEBTOR BANK  \
# 0                       SUMMARECON AGUNG  BANK BII MAYBANK
# 1                            SURAPANDANG  BANK BII MAYBANK
# 2                                BUDIMAN  BANK BII MAYBANK
# 3                                BUDIMAN  BANK BII MAYBANK
# 4                                BUDIMAN  BANK BII MAYBANK
# ...                                  ...               ...
# 191311              MITRA GLOBAL HOLIDAY  BANK BII MAYBANK
# 191312  LANDASAN SURYA TEKNIK MUTIARA TA  BANK BII MAYBANK
# 191313                     MANOHARA ASRI  BANK BII MAYBANK
# 191314                     MANOHARA ASRI  BANK BII MAYBANK
# 191315   LOGIQUE DIGITAL INDONESIA GD AD  BANK BII MAYBANK
#
#        SENDER/RECIPIENT ACCOUNT    SENDER/RECIPIENT NAME  \
# 0                    0701427009         SUMMARECON AGUNG
# 1                    2066770998  SWALLOW GLOBE INDONESIA
# 2                  162003012060                  NO DATA
# 3                             0                  NO DATA
# 4                             0                  NO DATA
# ...                         ...                      ...
# 191311                  NO DATA    ZANMEI TRAVEL LIMITED
# 191312                  NO DATA      ZEAL TRADING FZ LLC
# 191313                  NO DATA  ZOMEL MARKETING SDN BHD
# 191314                  NO DATA  ZOMEL MARKETING SDN BHD
# 191315                  NO DATA    ZUTTORIDE CORPORATION
#
#        SENDER/RECIPIENT BANK   LOB               REGION FUNDING/LENDING  \
# 0                   EXTERNAL    BB            JAKARTA 2         Funding
# 1                   EXTERNAL    BB       SULAWESI & IBT         Lending
# 2                   EXTERNAL  RSME                  ALL            Both
# 3                   EXTERNAL  RSME                  ALL            Both
# 4                   EXTERNAL  RSME                  ALL            Both
# ...                      ...   ...                  ...             ...
# 191311              EXTERNAL    BB            JAKARTA 1         Funding
# 191312              EXTERNAL    BB            JAKARTA 1         Funding
# 191313              EXTERNAL    BB  JATIM, BALI & NUSRA         Lending
# 191314              EXTERNAL    BB  JATIM, BALI & NUSRA         Lending
# 191315              EXTERNAL    BB            JAKARTA 1         Funding
#
#        CHANNEL      TYPE
# 0         RTGS  OUTGOING
# 1         RTGS  OUTGOING
# 2          M2U  OUTGOING
# 3          M2U  OUTGOING
# 4          M2U  OUTGOING
# ...        ...       ...
# 191311      TT  INCOMING
# 191312      TT  INCOMING
# 191313      TT  INCOMING
# 191314      TT  INCOMING
# 191315      TT  INCOMING
#
# [191316 rows x 14 columns]

# %%
gpd_data = data.groupby(['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME', 'SENDER/RECIPIENT BANK','LOB', 
'REGION' ,'FUNDING/LENDING','TYPE'])['AMOUNT_TX_IDR'].agg(AMOUNT_TX_IDR = 'sum',TRX='count')

# %%
gpd_data.reset_index(inplace=True)

# %%
gpd_data
# Out:
#       DEBTOR GCIF                       DEBTOR NAME       DEBTOR BANK  \
# 0      G000455626          PERMATA ASRIGRIYALESTARI  BANK BII MAYBANK
# 1      G000456624                  SUMMARECON AGUNG  BANK BII MAYBANK
# 2      G000457192                   INA PUBLIKATAMA  BANK BII MAYBANK
# 3      G000457192                   INA PUBLIKATAMA  BANK BII MAYBANK
# 4      G000457192                   INA PUBLIKATAMA  BANK BII MAYBANK
# ...           ...                               ...               ...
# 41204     NO DATA       INDOCEMENT TUNGGAL PRAKARSA  BANK BII MAYBANK
# 41205     NO DATA                           INDOSAT  BANK BII MAYBANK
# 41206     NO DATA       MABUCHI LOGISTICS INDONESIA  BANK BII MAYBANK
# 41207     NO DATA            TELEKOMUNIKASI SELULAR  BANK BII MAYBANK
# 41208     NO DATA  TOKIO MARINE LIFE INSURANCE INDO  BANK BII MAYBANK
#
#              SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK   LOB     REGION  \
# 0              BANK RAYA INDONESIA              EXTERNAL    GB        ALL
# 1                 SUMMARECON AGUNG              EXTERNAL    BB  JAKARTA 2
# 2                      BRI SPAN CN              EXTERNAL  RSME        ALL
# 3                        INDOFARMA              EXTERNAL  RSME        ALL
# 4                 KALBE FARMA (BO)              EXTERNAL  RSME        ALL
# ...                            ...                   ...   ...        ...
# 41204  INDOCEMENT TUNGGAL PRAKARSA              EXTERNAL    GB        ALL
# 41205                      INDOSAT              EXTERNAL    GB        ALL
# 41206  MABUCHI LOGISTICS INDONESIA              EXTERNAL  RSME        ALL
# 41207       TELEKOMUNIKASI SELULAR              EXTERNAL    GB        ALL
# 41208     TM USD MONEY MARKET FUND              EXTERNAL    GB        ALL
#
#       FUNDING/LENDING      TYPE  AMOUNT_TX_IDR  TRX
# 0                Both  INCOMING   2.703629e+06    3
# 1             Funding  OUTGOING   1.425000e+09    1
# 2                Both  INCOMING   1.064687e+07    1
# 3                Both  INCOMING   6.294150e+07    2
# 4                Both  INCOMING   3.483678e+07    2
# ...               ...       ...            ...  ...
# 41204            Both  OUTGOING   3.715621e+10    3
# 41205            Both  OUTGOING   1.003847e+08    1
# 41206            Both  OUTGOING   3.700559e+09    1
# 41207            Both  OUTGOING   1.386613e+08    3
# 41208            Both  OUTGOING   3.716693e+09    2
#
# [41209 rows x 11 columns]

# %%
gpd_data.to_excel('BB GPD.xlsx', index=False)

# %%
gpd_data[['FUNDING/LENDING','LOB']].value_counts()
# Out:
# FUNDING/LENDING  LOB
# Both             RSME    13809
# Lending          BB      12804
# Funding          BB      10816
# Both             SME+     2222
#                  GB       1558
# dtype: int64

# %%
current_data = pd.read_excel(r'C:\Users\MR38804\Documents\Network Graph\SME+ Request\SME+ Summary 2212_update.xlsx', sheet_name='Top 50 Funding Trx')

# %%
current_data
# Out:
#             GCIF                     CUST NAME   LOB  \
# 0     G000576256          HINI DAIKI INDONESIA  RSME
# 1     G000620575       EDDY SUHARTONO JULIANTO  RSME
# 2     G000630806           GUNAWAN EKA SETIONO  RSME
# 3     G000640193                   SURAPANDANG    BB
# 4     G000640193                   SURAPANDANG    BB
# ...          ...                           ...   ...
# 1161  G909576944       MITRA BELANJA SEJAHTERA  RSME
# 1162  G909592875         M TEK INNOVA GEMILANG  RSME
# 1163  G909618365           BENUA MEDIA DIGITAL  SME+
# 1164  G909686008       MOBIL ELEKTRIK NASIONAL  SME+
# 1165  G909692519  MOVUS TECHNOLOGIES INDONESIA  SME+
#
#             SENDER/RECIPIENT NAME      TYPE          REGION  AMOUNT_TX_IDR  \
# 0                BIROTIKA SEMESTA  OUTGOING      JAWA BARAT   4.932635e+07
# 1                           TEMPO  OUTGOING  SULAWESI & IBT   1.021951e+09
# 2          SUMBER ALFARIA TRIJAYA  INCOMING     JAWA TENGAH   2.086868e+07
# 3                HERO SUPERMARKET  INCOMING  SULAWESI & IBT   2.053236e+08
# 4         INDOFOOD FORTUNA MAKMUR  INCOMING  SULAWESI & IBT   1.070732e+08
# ...                           ...       ...             ...            ...
# 1161                        TEMPO  OUTGOING  SULAWESI & IBT   6.610301e+07
# 1162              SAYAP MAS UTAMA  INCOMING       JAKARTA 1   2.690713e+08
# 1163  FEDEX EXPRESS INTERNATIONAL  OUTGOING       JAKARTA 2   2.429000e+06
# 1164  FEDEX EXPRESS INTERNATIONAL  OUTGOING       JAKARTA 1   2.185000e+05
# 1165         GOTO GOJEK TOKOPEDIA  INCOMING       JAKARTA 1   4.898957e+06
#
#       TRX
# 0       2
# 1       1
# 2       6
# 3       5
# 4       4
# ...   ...
# 1161    5
# 1162    3
# 1163    1
# 1164    1
# 1165    1
#
# [1166 rows x 8 columns]

# %%
current_data['CUST BANK'] = 'BANK BII MAYBANK'
current_data['SENDER/RECIPIENT BANK'] = 'EXTERNAL'

# %%
current_data.columns
# Out:
# Index(['GCIF', 'CUST NAME', 'LOB', 'SENDER/RECIPIENT NAME', 'TYPE', 'REGION',
#        'AMOUNT_TX_IDR', 'TRX', 'CUST BANK', 'SENDER/RECIPIENT BANK'],
#       dtype='object')

# %%
current_data
# Out:
#             GCIF                     CUST NAME   LOB  \
# 0     G000576256          HINI DAIKI INDONESIA  RSME
# 1     G000620575       EDDY SUHARTONO JULIANTO  RSME
# 2     G000630806           GUNAWAN EKA SETIONO  RSME
# 3     G000640193                   SURAPANDANG    BB
# 4     G000640193                   SURAPANDANG    BB
# ...          ...                           ...   ...
# 1161  G909576944       MITRA BELANJA SEJAHTERA  RSME
# 1162  G909592875         M TEK INNOVA GEMILANG  RSME
# 1163  G909618365           BENUA MEDIA DIGITAL  SME+
# 1164  G909686008       MOBIL ELEKTRIK NASIONAL  SME+
# 1165  G909692519  MOVUS TECHNOLOGIES INDONESIA  SME+
#
#             SENDER/RECIPIENT NAME      TYPE          REGION  AMOUNT_TX_IDR  \
# 0                BIROTIKA SEMESTA  OUTGOING      JAWA BARAT   4.932635e+07
# 1                           TEMPO  OUTGOING  SULAWESI & IBT   1.021951e+09
# 2          SUMBER ALFARIA TRIJAYA  INCOMING     JAWA TENGAH   2.086868e+07
# 3                HERO SUPERMARKET  INCOMING  SULAWESI & IBT   2.053236e+08
# 4         INDOFOOD FORTUNA MAKMUR  INCOMING  SULAWESI & IBT   1.070732e+08
# ...                           ...       ...             ...            ...
# 1161                        TEMPO  OUTGOING  SULAWESI & IBT   6.610301e+07
# 1162              SAYAP MAS UTAMA  INCOMING       JAKARTA 1   2.690713e+08
# 1163  FEDEX EXPRESS INTERNATIONAL  OUTGOING       JAKARTA 2   2.429000e+06
# 1164  FEDEX EXPRESS INTERNATIONAL  OUTGOING       JAKARTA 1   2.185000e+05
# 1165         GOTO GOJEK TOKOPEDIA  INCOMING       JAKARTA 1   4.898957e+06
#
#       TRX         CUST BANK SENDER/RECIPIENT BANK
# 0       2  BANK BII MAYBANK              EXTERNAL
# 1       1  BANK BII MAYBANK              EXTERNAL
# 2       6  BANK BII MAYBANK              EXTERNAL
# 3       5  BANK BII MAYBANK              EXTERNAL
# 4       4  BANK BII MAYBANK              EXTERNAL
# ...   ...               ...                   ...
# 1161    5  BANK BII MAYBANK              EXTERNAL
# 1162    3  BANK BII MAYBANK              EXTERNAL
# 1163    1  BANK BII MAYBANK              EXTERNAL
# 1164    1  BANK BII MAYBANK              EXTERNAL
# 1165    1  BANK BII MAYBANK              EXTERNAL
#
# [1166 rows x 10 columns]

# %%
current_data = current_data.groupby(['GCIF', 'CUST NAME', 'CUST BANK', 'SENDER/RECIPIENT NAME',
       'SENDER/RECIPIENT BANK', 'LOB', 'TYPE']).agg({'AMOUNT_TX_IDR':'sum','TRX':'sum'})

# %%
current_data.reset_index(inplace=True)

# %%
current_data
# Out:
#             GCIF                     CUST NAME         CUST BANK  \
# 0     G000576256          HINI DAIKI INDONESIA  BANK BII MAYBANK
# 1     G000620575       EDDY SUHARTONO JULIANTO  BANK BII MAYBANK
# 2     G000630806           GUNAWAN EKA SETIONO  BANK BII MAYBANK
# 3     G000640193                   SURAPANDANG  BANK BII MAYBANK
# 4     G000640193                   SURAPANDANG  BANK BII MAYBANK
# ...          ...                           ...               ...
# 1161  G909576944       MITRA BELANJA SEJAHTERA  BANK BII MAYBANK
# 1162  G909592875         M TEK INNOVA GEMILANG  BANK BII MAYBANK
# 1163  G909618365           BENUA MEDIA DIGITAL  BANK BII MAYBANK
# 1164  G909686008       MOBIL ELEKTRIK NASIONAL  BANK BII MAYBANK
# 1165  G909692519  MOVUS TECHNOLOGIES INDONESIA  BANK BII MAYBANK
#
#             SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK   LOB      TYPE  \
# 0                BIROTIKA SEMESTA              EXTERNAL  RSME  OUTGOING
# 1                           TEMPO              EXTERNAL  RSME  OUTGOING
# 2          SUMBER ALFARIA TRIJAYA              EXTERNAL  RSME  INCOMING
# 3                HERO SUPERMARKET              EXTERNAL    BB  INCOMING
# 4         INDOFOOD FORTUNA MAKMUR              EXTERNAL    BB  INCOMING
# ...                           ...                   ...   ...       ...
# 1161                        TEMPO              EXTERNAL  RSME  OUTGOING
# 1162              SAYAP MAS UTAMA              EXTERNAL  RSME  INCOMING
# 1163  FEDEX EXPRESS INTERNATIONAL              EXTERNAL  SME+  OUTGOING
# 1164  FEDEX EXPRESS INTERNATIONAL              EXTERNAL  SME+  OUTGOING
# 1165         GOTO GOJEK TOKOPEDIA              EXTERNAL  SME+  INCOMING
#
#       AMOUNT_TX_IDR  TRX
# 0      4.932635e+07    2
# 1      1.021951e+09    1
# 2      2.086868e+07    6
# 3      2.053236e+08    5
# 4      1.070732e+08    4
# ...             ...  ...
# 1161   6.610301e+07    5
# 1162   2.690713e+08    3
# 1163   2.429000e+06    1
# 1164   2.185000e+05    1
# 1165   4.898957e+06    1
#
# [1166 rows x 9 columns]

# %%
current_data.columns
# Out:
# Index(['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME',
#        'SENDER/RECIPIENT BANK', 'LOB', 'REGION', 'FUNDING/LENDING', 'TYPE',
#        'AMOUNT_TX_IDR', 'TRX'],
#       dtype='object')

# %%
curr_gpd = current_data.groupby(['DEBTOR GCIF', 'DEBTOR NAME', 'DEBTOR BANK', 'SENDER/RECIPIENT NAME',
       'SENDER/RECIPIENT BANK', 'LOB', 'REGION', 'FUNDING/LENDING', 'TYPE']).agg({'AMOUNT_TX_IDR':'sum','TRX':'sum'})

# %%
curr_gpd
# Out:
#                                                                                                                                                        AMOUNT_TX_IDR  \
# DEBTOR GCIF DEBTOR NAME                    DEBTOR BANK      SENDER/RECIPIENT NAME  SENDER/RECIPIENT BANK LOB  REGION         FUNDING/LENDING TYPE
# G000630806  GUNAWAN EKA SETIONO            BANK BII MAYBANK SUMBER ALFARIA TRIJAYA EXTERNAL              RSME NON-BB         NON-BB          INCOMING   2.086868e+07
# G000640185  BII MAYBANK                    BANK BII MAYBANK SAUDARA SENDIRI        EXTERNAL              SME+ NON-BB         NON-BB          OUTGOING   6.600000e+09
# G000640193  SURAPANDANG                    BANK BII MAYBANK HERO SUPERMARKET       EXTERNAL              BB   SULAWESI & IBT Lending         INCOMING   2.053236e+08
#                                                             INTI CAKRAWALA CITRA   EXTERNAL              BB   SULAWESI & IBT Lending         INCOMING   3.585221e+09
#                                                             MIDI UTAMA INDONESIA   EXTERNAL              BB   SULAWESI & IBT Lending         INCOMING   9.194005e+09
# ...                                                                                                                                                              ...
# G909576944  CV MITRA BELANJA SEJAHTERA     BANK BII MAYBANK SUKANDA DJAYA          EXTERNAL              RSME NON-BB         NON-BB          INCOMING   3.000000e+06
#                                                                                                                                              OUTGOING   1.497026e+07
# G909645715  ALFA DINAMIS INDO TEHNIK       BANK BII MAYBANK MUSIM MAS              EXTERNAL              RSME NON-BB         NON-BB          INCOMING   1.293600e+07
#                                                             PRAKARSA ALAM SEGAR    EXTERNAL              RSME NON-BB         NON-BB          INCOMING   4.078760e+07
# G909692519  MOVUS TECHNOLOGIES INDONESIA P BANK BII MAYBANK TOKOPEDIA              EXTERNAL              SME+ NON-BB         NON-BB          INCOMING   4.898957e+06
#
#                                                                                                                                                        TRX
# DEBTOR GCIF DEBTOR NAME                    DEBTOR BANK      SENDER/RECIPIENT NAME  SENDER/RECIPIENT BANK LOB  REGION         FUNDING/LENDING TYPE
# G000630806  GUNAWAN EKA SETIONO            BANK BII MAYBANK SUMBER ALFARIA TRIJAYA EXTERNAL              RSME NON-BB         NON-BB          INCOMING    6
# G000640185  BII MAYBANK                    BANK BII MAYBANK SAUDARA SENDIRI        EXTERNAL              SME+ NON-BB         NON-BB          OUTGOING   22
# G000640193  SURAPANDANG                    BANK BII MAYBANK HERO SUPERMARKET       EXTERNAL              BB   SULAWESI & IBT Lending         INCOMING    5
#                                                             INTI CAKRAWALA CITRA   EXTERNAL              BB   SULAWESI & IBT Lending         INCOMING   28
#                                                             MIDI UTAMA INDONESIA   EXTERNAL              BB   SULAWESI & IBT Lending         INCOMING  108
# ...                                                                                                                                                    ...
# G909576944  CV MITRA BELANJA SEJAHTERA     BANK BII MAYBANK SUKANDA DJAYA          EXTERNAL              RSME NON-BB         NON-BB          INCOMING    3
#                                                                                                                                              OUTGOING    2
# G909645715  ALFA DINAMIS INDO TEHNIK       BANK BII MAYBANK MUSIM MAS              EXTERNAL              RSME NON-BB         NON-BB          INCOMING    1
#                                                             PRAKARSA ALAM SEGAR    EXTERNAL              RSME NON-BB         NON-BB          INCOMING    4
# G909692519  MOVUS TECHNOLOGIES INDONESIA P BANK BII MAYBANK TOKOPEDIA              EXTERNAL              SME+ NON-BB         NON-BB          INCOMING    1
#
# [1116 rows x 2 columns]

# %%
curr_gpd.reset_index(inplace=True)

# %%
curr_gpd
# Out:
#      DEBTOR GCIF                     DEBTOR NAME       DEBTOR BANK  \
# 0     G000630806             GUNAWAN EKA SETIONO  BANK BII MAYBANK
# 1     G000640185                     BII MAYBANK  BANK BII MAYBANK
# 2     G000640193                     SURAPANDANG  BANK BII MAYBANK
# 3     G000640193                     SURAPANDANG  BANK BII MAYBANK
# 4     G000640193                     SURAPANDANG  BANK BII MAYBANK
# ...          ...                             ...               ...
# 1111  G909576944      CV MITRA BELANJA SEJAHTERA  BANK BII MAYBANK
# 1112  G909576944      CV MITRA BELANJA SEJAHTERA  BANK BII MAYBANK
# 1113  G909645715        ALFA DINAMIS INDO TEHNIK  BANK BII MAYBANK
# 1114  G909645715        ALFA DINAMIS INDO TEHNIK  BANK BII MAYBANK
# 1115  G909692519  MOVUS TECHNOLOGIES INDONESIA P  BANK BII MAYBANK
#
#        SENDER/RECIPIENT NAME SENDER/RECIPIENT BANK   LOB          REGION  \
# 0     SUMBER ALFARIA TRIJAYA              EXTERNAL  RSME          NON-BB
# 1            SAUDARA SENDIRI              EXTERNAL  SME+          NON-BB
# 2           HERO SUPERMARKET              EXTERNAL    BB  SULAWESI & IBT
# 3       INTI CAKRAWALA CITRA              EXTERNAL    BB  SULAWESI & IBT
# 4       MIDI UTAMA INDONESIA              EXTERNAL    BB  SULAWESI & IBT
# ...                      ...                   ...   ...             ...
# 1111           SUKANDA DJAYA              EXTERNAL  RSME          NON-BB
# 1112           SUKANDA DJAYA              EXTERNAL  RSME          NON-BB
# 1113               MUSIM MAS              EXTERNAL  RSME          NON-BB
# 1114     PRAKARSA ALAM SEGAR              EXTERNAL  RSME          NON-BB
# 1115               TOKOPEDIA              EXTERNAL  SME+          NON-BB
#
#      FUNDING/LENDING      TYPE  AMOUNT_TX_IDR  TRX
# 0             NON-BB  INCOMING   2.086868e+07    6
# 1             NON-BB  OUTGOING   6.600000e+09   22
# 2            Lending  INCOMING   2.053236e+08    5
# 3            Lending  INCOMING   3.585221e+09   28
# 4            Lending  INCOMING   9.194005e+09  108
# ...              ...       ...            ...  ...
# 1111          NON-BB  INCOMING   3.000000e+06    3
# 1112          NON-BB  OUTGOING   1.497026e+07    2
# 1113          NON-BB  INCOMING   1.293600e+07    1
# 1114          NON-BB  INCOMING   4.078760e+07    4
# 1115          NON-BB  INCOMING   4.898957e+06    1
#
# [1116 rows x 11 columns]

# %%
current_data =  curr_gpd

# %%
list_entity=current_data['CUST NAME'].values.tolist()
list_entity+=current_data['SENDER/RECIPIENT NAME'].values.tolist()
list_entity=pd.DataFrame({
    'ENTITY NAME':list_entity
})
list_entity=list_entity.drop_duplicates(keep='first')

# %%
list_entity
# Out:
#                      ENTITY NAME
# 0           HINI DAIKI INDONESIA
# 1        EDDY SUHARTONO JULIANTO
# 2            GUNAWAN EKA SETIONO
# 3                    SURAPANDANG
# 10                          ORIX
# ...                          ...
# 1372               DNP INDONESIA
# 1426          ASTRA DIGITAL ARTA
# 1434  INDONESIA STANLEY ELECTRIC
# 1454        TIRTA SUKSES PERKASA
# 1479      FRISIAN FLAG INDONESIA
#
# [743 rows x 1 columns]

# %%
list_entity.loc[list_entity['ENTITY NAME'].str.contains('AVOLON')]
# Out:
# Empty DataFrame
# Columns: [ENTITY NAME]
# Index: []

# %%
entity_CUST=list(set(current_data['CUST NAME']))
all_entity=list_entity['ENTITY NAME'].values.tolist()
sr_entity_data=[]
for name in all_entity:
    placeholder=''
    as_CUST=current_data.loc[current_data['CUST NAME']==name]
    as_other  =current_data.loc[current_data['SENDER/RECIPIENT NAME']==name]
    
    #if in CUST, incoming -> receiver with Maybank bank, outgoing -> sender with Maybank bank
    if len(as_CUST)!=0: #pernah menjadi customer maybank
        if 'INCOMING' in as_CUST['TYPE'].values and 'OUTGOING' in as_CUST['TYPE'].values:
            sr_entity_data.append([name,'Both',as_CUST['CUST BANK'].iloc[0]])
        elif 'INCOMING' in as_CUST['TYPE'].values:
            sr_entity_data.append([name,'Receiver',as_CUST['CUST BANK'].iloc[0]])
        elif 'OUTGOING' in as_CUST['TYPE'].values:
            sr_entity_data.append([name,'Sender',as_CUST['CUST BANK'].iloc[0]])
    
    #if in sender/recipient, incoming -> sender with SR bank name, outgoing -> recipient with SR bank name
    if len(as_other)!=0: #pernah transaksi dgn rek Maybank sebagai nasabah bank lain
        sr_bank_names=list(set(as_other['SENDER/RECIPIENT BANK']))
        for bank in sr_bank_names:
            as_other_bank=as_other.loc[as_other['SENDER/RECIPIENT BANK']==bank]
            if 'INCOMING' in as_other_bank['TYPE'].values and 'OUTGOING' in as_other_bank['TYPE'].values:
                sr_entity_data.append([name,'Both',bank])
            elif 'INCOMING' in as_other_bank['TYPE'].values:
                sr_entity_data.append([name,'Sender',bank])
            elif 'OUTGOING' in as_other_bank['TYPE'].values:
                sr_entity_data.append([name,'Receiver',bank])

sr_entity_df=pd.DataFrame(sr_entity_data,columns=['NAME','DIRECTION','BANK'])
sr_entity_df
# Out:
#                            NAME DIRECTION              BANK
# 0          HINI DAIKI INDONESIA    Sender  BANK BII MAYBANK
# 1       EDDY SUHARTONO JULIANTO    Sender  BANK BII MAYBANK
# 2           GUNAWAN EKA SETIONO  Receiver  BANK BII MAYBANK
# 3                   SURAPANDANG      Both  BANK BII MAYBANK
# 4                          ORIX    Sender  BANK BII MAYBANK
# ..                          ...       ...               ...
# 738               DNP INDONESIA      Both          EXTERNAL
# 739          ASTRA DIGITAL ARTA      Both          EXTERNAL
# 740  INDONESIA STANLEY ELECTRIC      Both          EXTERNAL
# 741        TIRTA SUKSES PERKASA      Both          EXTERNAL
# 742      FRISIAN FLAG INDONESIA      Both          EXTERNAL
#
# [743 rows x 3 columns]

# %%
sr_entity_df.loc[sr_entity_df['NAME'].str.contains('AVOLON')]
# Out:
# Empty DataFrame
# Columns: [NAME, DIRECTION, BANK]
# Index: []

# %%
#merge gcif
gcif_copying=current_data[['CUST NAME','GCIF']]
gcif_copying.columns=['NAME','GCIF']

sr_entity_df=sr_entity_df.merge(gcif_copying,on='NAME',how='left')
sr_entity_df=sr_entity_df.fillna('External')

sr_entity_df=sr_entity_df.drop_duplicates()
sr_entity_df
# Out:
#                             NAME DIRECTION              BANK        GCIF
# 0           HINI DAIKI INDONESIA    Sender  BANK BII MAYBANK  G000576256
# 1        EDDY SUHARTONO JULIANTO    Sender  BANK BII MAYBANK  G000620575
# 2            GUNAWAN EKA SETIONO  Receiver  BANK BII MAYBANK  G000630806
# 3                    SURAPANDANG      Both  BANK BII MAYBANK  G000640193
# 10                          ORIX    Sender  BANK BII MAYBANK  G000649251
# ...                          ...       ...               ...         ...
# 1211               DNP INDONESIA      Both          EXTERNAL    External
# 1212          ASTRA DIGITAL ARTA      Both          EXTERNAL    External
# 1213  INDONESIA STANLEY ELECTRIC      Both          EXTERNAL    External
# 1214        TIRTA SUKSES PERKASA      Both          EXTERNAL    External
# 1215      FRISIAN FLAG INDONESIA      Both          EXTERNAL    External
#
# [744 rows x 4 columns]

# %% [markdown]
# ### Create entity data - Coloring
#
# - Internal
#  - In: orange
#  - Out: purple
#  - Both: lightblue
# - External
#  - In: black
#  - Out: red
#  - Both: lightgreen

# %%
row=[sr_entity_df.iloc[0]['NAME'],sr_entity_df.iloc[0]['DIRECTION'],sr_entity_df.iloc[0]['BANK']]
'MAYBANK' in row[2]
# Out:
# True

# %%
#'MBI Out','MBI In','MBI Both','Non-MBI Out','Non-MBI In','Non-MBI Both'),
# color=c("#3333ff","#00bf30","orange","#685b5b","#c071f1","#ff0000"))
final_entity_df=[]
for i in range(len(sr_entity_df)):
    row=sr_entity_df.iloc[i]
    row=[row['NAME'],row['DIRECTION'],row['BANK'],row['GCIF']
         #,row['LOB']
        ]
    
    #row color (based on internal/external)
    if 'MAYBANK' in row[2]: #internal
        if row[1]=='Both':
            row+=['MBI Both','orange']
        elif row[1]=='Receiver':
            row+=['MBI In','#00bf30']
        else:
            row+=['MBI Out','#3333ff']
    else:
        if row[1]=='Both':
            row+=['Non-MBI Both','#ff0000']
        elif row[1]=='Receiver':
            row+=['Non-MBI In','#c071f1']
        else:
            row+=['Non-MBI Out','#685b5b']
    
    #row shape (semuanya dot) -> uncomment if needed
    row+=['dot']
    #row shape (tergantung lob) -> uncomment if needed
    #if row[4] == 'Consumer':
    #    row+=['square']
    #elif row[4] == 'RSME':
    #    row+=['triangle']
    #elif row[4] == 'SME+':
    #    row+=['triangleDown']
    #elif row[4] == 'Corporate':
    #    row+=['star']
    #elif row[4] == 'Commercial (BB)':
    #    row+=['diamond']
    #else :
    #    row+=['dot']

    
    #row id (tambahin i)
    row+=[i]
    
    #append
    final_entity_df.append(row)
    
final_entity_df=pd.DataFrame(final_entity_df,
                             columns=['ENTITY','DIRECTION','SOURCE','GCIF',
                                      #'LOB',
                                      'TYPE','COLOR','SHAPE','ID'])
final_entity_df=final_entity_df.drop_duplicates()
final_entity_df
# Out:
#                          ENTITY DIRECTION            SOURCE        GCIF  \
# 0          HINI DAIKI INDONESIA    Sender  BANK BII MAYBANK  G000576256
# 1       EDDY SUHARTONO JULIANTO    Sender  BANK BII MAYBANK  G000620575
# 2           GUNAWAN EKA SETIONO  Receiver  BANK BII MAYBANK  G000630806
# 3                   SURAPANDANG      Both  BANK BII MAYBANK  G000640193
# 4                          ORIX    Sender  BANK BII MAYBANK  G000649251
# ..                          ...       ...               ...         ...
# 739               DNP INDONESIA      Both          EXTERNAL    External
# 740          ASTRA DIGITAL ARTA      Both          EXTERNAL    External
# 741  INDONESIA STANLEY ELECTRIC      Both          EXTERNAL    External
# 742        TIRTA SUKSES PERKASA      Both          EXTERNAL    External
# 743      FRISIAN FLAG INDONESIA      Both          EXTERNAL    External
#
#              TYPE    COLOR SHAPE   ID
# 0         MBI Out  #3333ff   dot    0
# 1         MBI Out  #3333ff   dot    1
# 2          MBI In  #00bf30   dot    2
# 3        MBI Both   orange   dot    3
# 4         MBI Out  #3333ff   dot    4
# ..            ...      ...   ...  ...
# 739  Non-MBI Both  #ff0000   dot  739
# 740  Non-MBI Both  #ff0000   dot  740
# 741  Non-MBI Both  #ff0000   dot  741
# 742  Non-MBI Both  #ff0000   dot  742
# 743  Non-MBI Both  #ff0000   dot  743
#
# [744 rows x 8 columns]

# %%
final_entity_df.loc[final_entity_df['ENTITY'].str.contains('GATEWAY CONTAINER LINE')]
# Out:
#                      ENTITY DIRECTION            SOURCE        GCIF    TYPE  \
# 159  GATEWAY CONTAINER LINE  Receiver  BANK BII MAYBANK  G203736616  MBI In
#
#        COLOR SHAPE   ID
# 159  #00bf30   dot  159

# %% [markdown]
# ### Create trans data

# %% [markdown]
# Run this block if we only consider names for entities

# %%
trans_id=[]
for i in range(len(current_data)):
    row=current_data.iloc[i]
    
    if row['TYPE']=='INCOMING': #CUST nerima, sr ngirim
        trans_id.append([row['SENDER/RECIPIENT NAME'],row['SENDER/RECIPIENT BANK'],
                         row['CUST NAME'],row['CUST BANK'],
                         row['AMOUNT_TX_IDR'],row['TRX']])
    else: #CUST ngirim, sr nerima
        trans_id.append([row['CUST NAME'],row['CUST BANK'],
                         row['SENDER/RECIPIENT NAME'],row['SENDER/RECIPIENT BANK'],
                         row['AMOUNT_TX_IDR'],row['TRX']])
    
#create trans_df
trans_id=pd.DataFrame(trans_id,columns=['FROM_ENTITY','FROM_SOURCE','TO_ENTITY','TO_SOURCE','AMOUNT_TX_IDR','TRX'])

#get FROM_ID using entity data
temp=final_entity_df[['ENTITY','SOURCE','ID']].copy()
temp.columns=['FROM_ENTITY','FROM_SOURCE','FROM_ID']
trans_id=trans_id.merge(temp,on=['FROM_ENTITY','FROM_SOURCE'],how='left')

#get TO_ID using entity data
temp=final_entity_df[['ENTITY','SOURCE','ID']].copy()
temp.columns=['TO_ENTITY','TO_SOURCE','TO_ID']
trans_id=trans_id.merge(temp,on=['TO_ENTITY','TO_SOURCE'],how='left')

#trans_id=trans_id[['FROM_ID','TO_ID','AMOUNT_TX_IDR']]
trans_id=trans_id.drop_duplicates()
trans_id
# Out:
#                   FROM_ENTITY       FROM_SOURCE                     TO_ENTITY  \
# 0        HINI DAIKI INDONESIA  BANK BII MAYBANK              BIROTIKA SEMESTA
# 1     EDDY SUHARTONO JULIANTO  BANK BII MAYBANK                         TEMPO
# 2      SUMBER ALFARIA TRIJAYA          EXTERNAL           GUNAWAN EKA SETIONO
# 3            HERO SUPERMARKET          EXTERNAL                   SURAPANDANG
# 4     INDOFOOD FORTUNA MAKMUR          EXTERNAL                   SURAPANDANG
# ...                       ...               ...                           ...
# 1163  MITRA BELANJA SEJAHTERA  BANK BII MAYBANK                         TEMPO
# 1164          SAYAP MAS UTAMA          EXTERNAL         M TEK INNOVA GEMILANG
# 1165      BENUA MEDIA DIGITAL  BANK BII MAYBANK   FEDEX EXPRESS INTERNATIONAL
# 1166  MOBIL ELEKTRIK NASIONAL  BANK BII MAYBANK   FEDEX EXPRESS INTERNATIONAL
# 1167     GOTO GOJEK TOKOPEDIA          EXTERNAL  MOVUS TECHNOLOGIES INDONESIA
#
#              TO_SOURCE  AMOUNT_TX_IDR  TRX  FROM_ID  TO_ID
# 0             EXTERNAL   4.932635e+07    2        0    694
# 1             EXTERNAL   1.021951e+09    1        1    695
# 2     BANK BII MAYBANK   2.086868e+07    6      696      2
# 3     BANK BII MAYBANK   2.053236e+08    5      697      3
# 4     BANK BII MAYBANK   1.070732e+08    4      698      3
# ...                ...            ...  ...      ...    ...
# 1163          EXTERNAL   6.610301e+07    5      689    695
# 1164  BANK BII MAYBANK   2.690713e+08    3      712    690
# 1165          EXTERNAL   2.429000e+06    1      691    704
# 1166          EXTERNAL   2.185000e+05    1      692    704
# 1167  BANK BII MAYBANK   4.898957e+06    1      722    693
#
# [1168 rows x 8 columns]

# %%
#create initial size
size_amount=[]
size_count=[]
size_chain=[]
for name in final_entity_df['ID'].values:
    curr_agg=trans_id.loc[(trans_id['FROM_ID']==name)|(trans_id['TO_ID']==name)]
    size_amount.append(sum(curr_agg['AMOUNT_TX_IDR']))
    size_count.append(sum(curr_agg['TRX']))
    size_chain.append(len(curr_agg))

final_entity_df['ORIG_AMOUNT']=size_amount
final_entity_df['ORIG_COUNT']=size_count
final_entity_df['ORIG_CHAIN']=size_chain

final_entity_df['SIZE_AMOUNT']=[1 if i<=1 else i for i in size_amount]
final_entity_df['SIZE_COUNT']=[1 if i<=1 else i for i in size_count]
final_entity_df['SIZE_CHAIN']=[1 if i<=1 else i for i in size_chain]

#create individual flags
final_entity_df['FLAG_AMT']=final_entity_df['SIZE_AMOUNT'].apply(lambda x: 'high amt' if x>=34 else 'low amt')
final_entity_df['FLAG_TRX']=final_entity_df['SIZE_COUNT'].apply(lambda x: 'high freq' if x>=4 else 'low freq')
final_entity_df['FLAG_CHAIN']=final_entity_df['SIZE_CHAIN'].apply(lambda x: 'high chain' if x>=10 else 'low chain')

#create final filter
final_filter=[]
simplified=[]
for i in range(len(final_entity_df)):
    row=final_entity_df.iloc[i]
    curr_filter=''
    
    #final filter
    if row['FLAG_AMT']=='high amt':
        curr_filter+='high amt, '
    if row['FLAG_TRX']=='high freq':
        curr_filter+='high freq, '
    if row['FLAG_CHAIN']=='high chain':
        curr_filter+='high chain, '
    if curr_filter=='':
        curr_filter='low, '
    
    #simplified view
    if row['SIZE_CHAIN']>=2:
        curr_filter+='full'
        simplified.append('full')
    else:
        simplified.append('full')
        
    #remove trailing comma and whitespace
    curr_filter=curr_filter.rstrip(' ')
    curr_filter=curr_filter.rstrip(',')
    
    #append
    final_filter.append(curr_filter+'')

final_entity_df['FILTER']=final_filter
final_entity_df['SIMPLIFIED']=simplified
#final_entity_df['FLAG_LOB']=final_entity_df['LOB']+', '+final_entity_df['SIMPLIFIED']

# %%
final_entity_df
# Out:
#                          ENTITY DIRECTION            SOURCE        GCIF  \
# 0          HINI DAIKI INDONESIA    Sender  BANK BII MAYBANK  G000576256
# 1       EDDY SUHARTONO JULIANTO    Sender  BANK BII MAYBANK  G000620575
# 2           GUNAWAN EKA SETIONO  Receiver  BANK BII MAYBANK  G000630806
# 3                   SURAPANDANG      Both  BANK BII MAYBANK  G000640193
# 4                          ORIX    Sender  BANK BII MAYBANK  G000649251
# ..                          ...       ...               ...         ...
# 739               DNP INDONESIA      Both          EXTERNAL    External
# 740          ASTRA DIGITAL ARTA      Both          EXTERNAL    External
# 741  INDONESIA STANLEY ELECTRIC      Both          EXTERNAL    External
# 742        TIRTA SUKSES PERKASA      Both          EXTERNAL    External
# 743      FRISIAN FLAG INDONESIA      Both          EXTERNAL    External
#
#              TYPE    COLOR SHAPE   ID   ORIG_AMOUNT  ORIG_COUNT  ORIG_CHAIN  \
# 0         MBI Out  #3333ff   dot    0  4.932635e+07           2           1
# 1         MBI Out  #3333ff   dot    1  1.021951e+09           1           1
# 2          MBI In  #00bf30   dot    2  2.086868e+07           6           1
# 3        MBI Both   orange   dot    3  1.749571e+10         194           7
# 4         MBI Out  #3333ff   dot    4  1.183750e+08           5           1
# ..            ...      ...   ...  ...           ...         ...         ...
# 739  Non-MBI Both  #ff0000   dot  739  4.996577e+09          97          17
# 740  Non-MBI Both  #ff0000   dot  740  1.934898e+10         110           6
# 741  Non-MBI Both  #ff0000   dot  741  1.291036e+10          28          13
# 742  Non-MBI Both  #ff0000   dot  742  1.847686e+10          42           9
# 743  Non-MBI Both  #ff0000   dot  743  6.175138e+09          42          11
#
#       SIZE_AMOUNT  SIZE_COUNT  SIZE_CHAIN  FLAG_AMT   FLAG_TRX  FLAG_CHAIN  \
# 0    4.932635e+07           2           1  high amt   low freq   low chain
# 1    1.021951e+09           1           1  high amt   low freq   low chain
# 2    2.086868e+07           6           1  high amt  high freq   low chain
# 3    1.749571e+10         194           7  high amt  high freq   low chain
# 4    1.183750e+08           5           1  high amt  high freq   low chain
# ..            ...         ...         ...       ...        ...         ...
# 739  4.996577e+09          97          17  high amt  high freq  high chain
# 740  1.934898e+10         110           6  high amt  high freq   low chain
# 741  1.291036e+10          28          13  high amt  high freq  high chain
# 742  1.847686e+10          42           9  high amt  high freq   low chain
# 743  6.175138e+09          42          11  high amt  high freq  high chain
#
#                                     FILTER SIMPLIFIED
# 0                                 high amt       full
# 1                                 high amt       full
# 2                      high amt, high freq       full
# 3                high amt, high freq, full       full
# 4                      high amt, high freq       full
# ..                                     ...        ...
# 739  high amt, high freq, high chain, full       full
# 740              high amt, high freq, full       full
# 741  high amt, high freq, high chain, full       full
# 742              high amt, high freq, full       full
# 743  high amt, high freq, high chain, full       full
#
# [744 rows x 19 columns]

# %%
final_entity_df.to_csv('SME+ 50_entityV3_id.csv')
trans_id.to_csv('SME+ 50_transV3_id.csv')
